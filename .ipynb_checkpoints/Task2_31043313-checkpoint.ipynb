# %% [markdown]
# # FIT5196 Assessment 1 : Task 2
# #### Student Name: Md. Saadman Hossain
# #### Student ID: 31043313
#
#
#
#
#
#
# Libraries used:
#
#     import pandas as pd
#     import langid
#     import re
#     import os
#     import nltk
#     from nltk.collocations import *
#     from itertools import chain
#     import itertools
#     from nltk.tokenize import RegexpTokenizer
#     from nltk.tokenize import MWETokenizer
#     from nltk.stem import PorterStemmer
#     from sklearn.feature_extraction.text import CountVectorizer
#     from nltk.probability import FreqDist
#     from nltk.tokenize import MWETokenizer
#
#
# ## 1. Introduction
#
#     This assessment touches on the next step of analyzing textual data, i.e., converting the extracted
#     data into a proper format. In this assessment, i am required to write Python code to
#     preprocess a set of tweets and convert them into numerical representations.
#
# 1. Generate the corpus vocabulary with the same structure as sample_vocab.txt. Please
#     note that the vocabulary must be sorted alphabetically.
# 2. For each day (i.e., sheet in your excel file), calculate the top 100 frequent unigram and
#     top-100 frequent bigrams according to the structure of the sample_100uni.txt and
#     sample_100bi.txt. If you have less than 100 bigrams for a particular day, just include the
#     top-n bigrams for that day (n<100).
# 3. Generate the sparse representation (i.e., doc-term matrix) of the excel file according to
#     the structure of the sample_countVec.txt
#
#
# More details for each task will be given in the following sections.

# %% [markdown]
# # Task 2: Text Pre-Processing (%45)

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import langid
import re
import os
import nltk
from nltk.collocations import *
from itertools import chain
import itertools
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import MWETokenizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.probability import FreqDist
from nltk.tokenize import MWETokenizer

# %% [markdown]
# ## Firstly, i decided to read the excel file into a pandas dataframe using the ExcelFile pandas functions. I was able to achieve this by:
#
# #### 1. Iterating through all the sheet names and parsing the sheets.
# #### 2. dropping all columns with nulls for each sheet while appending and drop all rows with nulls at the same time
# #### 3. used pd.concat to merge all the dataframes, removed repeated text, id, created at columns
# #### 4. renamed the columns
# #### 5. reset row index

# %%
# reading excel file

data = pd.ExcelFile('31043313.xlsx')
df = []
for sheet in data.sheet_names:
    df.append(data.parse(sheet)
                         .dropna(axis = 0, how ='all')
                         .dropna(axis = 1, how ='all').T.reset_index(drop=True).T)
    
df = pd.concat(df)

df = df[df[0] != 'text']
print(len(df))    
    
df.columns = ['text', 'id', 'created_at']


#reset dataframe index

df = df.reset_index(drop=True)

df.head()
# Out:
# 162000
#                                                 text                   id  \
# 0  These are tough times, the president has to ad...  1241652580637344000
# 1               @OosiTappasu https://t.co/OOQXC15j6q  1241727281749344000
# 2  We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 3  En serio, el Gobierno y todos sus ministerios ...  1241637670788488960
# 4  An open letter - signed by cca. 1000 scholars ...  1241712869894430976
#
#                  created_at
# 0  2020-03-22T09:06:58.000Z
# 1  2020-03-22T14:03:48.000Z
# 2  2020-03-22T05:18:45.000Z
# 3  2020-03-22T08:07:43.000Z
# 4  2020-03-22T13:06:32.000Z

# %%
langid.classify(str(df['text'][0]))
# Out:
# ('en', -180.16161918640137)

# %% [markdown]
# ## Using langid.classify function to remove rows in my dataframe which have text not in english

# %%
#classifying the dataframe using langid, keeping only the english tweets

#remove non english tweets from the dataframe
for i in range(len(df['text'])):
    if langid.classify(str(df['text'][i]))[0] != 'en':
        df = df.drop([i])
        
print(len(df))
# Out:
# 91370

# %%
#resetting index
df = df.reset_index(drop=True)
df.head()
# Out:
#                                                 text                   id  \
# 0  These are tough times, the president has to ad...  1241652580637344000
# 1  We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 2  An open letter - signed by cca. 1000 scholars ...  1241712869894430976
# 3  Please remember each time you choose to buy si...  1241687033485168896
# 4  The people of India have decided- we are in th...  1241633333383172096
#
#                  created_at
# 0  2020-03-22T09:06:58.000Z
# 1  2020-03-22T05:18:45.000Z
# 2  2020-03-22T13:06:32.000Z
# 3  2020-03-22T11:23:52.000Z
# 4  2020-03-22T07:50:29.000Z

# %% [markdown]
# ## Removing time from created at column for creating of a key value pair dictionary with dates as keys, and text as values.

# %%
#removing time from created at

df[['created_at','extra_col']] = df['created_at'].str.split('T',expand=True)
df = df.drop(columns = ['extra_col'])
df.head()
# Out:
#                                                 text                   id  \
# 0  These are tough times, the president has to ad...  1241652580637344000
# 1  We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 2  An open letter - signed by cca. 1000 scholars ...  1241712869894430976
# 3  Please remember each time you choose to buy si...  1241687033485168896
# 4  The people of India have decided- we are in th...  1241633333383172096
#
#    created_at
# 0  2020-03-22
# 1  2020-03-22
# 2  2020-03-22
# 3  2020-03-22
# 4  2020-03-22

# %% [markdown]
# ## Creating a dictionary with dates as key and text and values

# %%
newdf = df

#creating a dictionary with dates as key and text and values
dict1 = newdf.groupby('created_at')['text'].apply(list).to_dict()


print(len(dict1))
# Out:
# 81

# %%
len(dict1['2020-03-22'])
# Out:
# 1105

# %%
#checking if dictionary is created well

k = 0

for i in dict1.keys():
    k+=len(dict1[i])
    
print(k)
# Out:
# 91370

# %% [markdown]
# ## Tokenizing the text in the dictionary and then adding the tokenized words into a list

# %%
# tokenizing the words

tokenized_words = []

for items in list(dict1.keys()):
    
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
    tokens = tokenizer.tokenize(str(dict1[items]).lower()) # converting all the tokens to lower case
    tokenized_words += tokens

len(tokenized_words)
# Out:
# 2347201

# %%
tokenized_words[0:20]
# Out:
# ['these',
#  'are',
#  'tough',
#  'times',
#  'the',
#  'president',
#  'has',
#  'to',
#  'address',
#  'the',
#  'nation',
#  'twice',
#  'a',
#  'week',
#  'https',
#  't',
#  'co',
#  'puqbod',
#  'quq',
#  'we']

# %% [markdown]
# ## Finding top 200 meaningful bigrams using pmi

# %%
#finding top 200 meaningful bigrams using pmi
bigram_measures = nltk.collocations.BigramAssocMeasures()

finder = nltk.collocations.BigramCollocationFinder.from_words(tokenized_words)

finder.apply_freq_filter(20)
finder.apply_word_filter(lambda w: len(w) < 3)

meaningful_bigrams = finder.nbest(bigram_measures.pmi, 200)

# creating bigram words to add to vocab
pmi_bigrams = []
for word in meaningful_bigrams:
    pmi_bigrams.append('_'.join(word))
    
    
pmi_bigrams
# Out:
# ['janeruth_aceng',
#  'cummads_sexhookups',
#  'achyuta_samanta',
#  'amici_siamo',
#  'cari_amici',
#  'fantasticradiouk_homeofpossibilities',
#  'homeofpossibilities_believeyourpossibilities',
#  'believeyourpossibilities_stayhomesafelives',
#  'jacinda_ardern',
#  'ruby_princess',
#  'johns_hopkins',
#  'abba_kyari',
#  'tamil_nadu',
#  'arvind_kejriwal',
#  'los_angeles',
#  'aarogya_setu',
#  'cumm_ads',
#  'con_voi',
#  'siamo_con',
#  'sri_lanka',
#  'las_vegas',
#  'saudi_arabia',
#  'silver_lining',
#  'jared_kushner',
#  'keir_starmer',
#  'uttar_pradesh',
#  'madhya_pradesh',
#  'piers_morgan',
#  'hong_kong',
#  'rahul_gandhi',
#  'wwg_wga',
#  'planned_parenthood',
#  'jim_jordan',
#  'san_francisco',
#  'andhra_pradesh',
#  'artificial_intelligence',
#  'prince_charles',
#  'hello_fantasticradio',
#  'recommend_aarogya',
#  'matt_hancock',
#  'cruise_ships',
#  'hot_spots',
#  'retention_scheme',
#  'nancy_pelosi',
#  'george_floyd',
#  'critically_ill',
#  'dominic_cummings',
#  'supreme_court',
#  'obamagate_obamagate',
#  'truck_drivers',
#  'premier_league',
#  'nmay_nmay',
#  'injecting_disinfectant',
#  'toilet_paper',
#  'up-to_date',
#  'cruise_ship',
#  'mike_pence',
#  'conspiracy_theories',
#  'narendra_modi',
#  'armed_forces',
#  'sars_cov',
#  'north_carolina',
#  'supply_chains',
#  'nvia_namo',
#  'zero_hedge',
#  'town_hall',
#  'jesus_christ',
#  'moh_kenya',
#  'adding_value',
#  'suggests_limiting',
#  'herd_immunity',
#  'plasma_therapy',
#  'held_accountable',
#  'loved_ones',
#  'martial_law',
#  'anthony_fauci',
#  'west_bengal',
#  'task_force',
#  'wet_markets',
#  'grocery_store',
#  'ads_suggests',
#  'northern_ireland',
#  'nvia_googlenews',
#  'supply_chain',
#  'per_capita',
#  'protective_gear',
#  'conspiracy_theory',
#  'domestic_abuse',
#  'middle_east',
#  'wall_street',
#  'joe_biden',
#  'clinical_trials',
#  'united_kingdom',
#  'protective_equipment',
#  'per_cent',
#  'shaking_hands',
#  'swine_flu',
#  'front_lines',
#  'domestic_violence',
#  'human_beings',
#  'hand_sanitizer',
#  'speedy_recovery',
#  'jobless_claims',
#  "boris_johnson's",
#  'hot_spot',
#  'universal_credit',
#  'press_conference',
#  'boris_johnson',
#  'beaten_play',
#  'bay_area',
#  'namo_app',
#  'andrew_cuomo',
#  'police_brutality',
#  'infectious_diseases',
#  'exit_strategy',
#  'prime_minister',
#  'job_retention',
#  'air_pollution',
#  'bill_gates',
#  'clinical_trial',
#  'setu_app',
#  'contact_tracing',
#  'face_coverings',
#  'south_korea',
#  'law_enforcement',
#  'nursing_homes',
#  'preventive_measures',
#  'family_cari',
#  'precautionary_measures',
#  'latin_america',
#  'cured_discharged',
#  'fatality_rate',
#  'common_sense',
#  'god_bless',
#  'second_wave',
#  'personal_protective',
#  'oil_prices',
#  'face_shields',
#  'communist_party',
#  'buy_song',
#  'seasonal_flu',
#  'real_estate',
#  'common_cold',
#  'middle_class',
#  'nlatest_updates',
#  'hand_washing',
#  'stimulus_package',
#  'link_android',
#  'narendramodi_amitshah',
#  'limiting_person',
#  'epoch_times',
#  'side_effects',
#  'white_house',
#  'spanish_flu',
#  'front_line',
#  'european_union',
#  'pregnant_women',
#  'immune_system',
#  'south_korean',
#  'raise_awareness',
#  'national_guard',
#  'mainstream_media',
#  'climate_change',
#  'italian_friends',
#  'social_distancing',
#  'happy_birthday',
#  'hardest_hit',
#  'unemployment_benefits',
#  'further_notice',
#  'intensive_care',
#  'united_states',
#  'laid_off',
#  'toll_nears',
#  'big_pharma',
#  'long_term',
#  'shutting_down',
#  'mortality_rate',
#  'study_finds',
#  'tally_rises',
#  'taking_advantage',
#  'difference_between',
#  'human_rights',
#  'bbcr_today',
#  'vice_president',
#  'business_insider',
#  'press_briefing',
#  'chief_executive',
#  'colleagues_friends',
#  'day_oflockdown',
#  'infectious_disease',
#  'washington_post',
#  'lock_down',
#  'front_page',
#  'south_africans',
#  'first_responders',
#  'stock_market',
#  'job_losses',
#  'looking_forward',
#  'united_nations',
#  'wuhan_lab']

# %% [markdown]
# ## Creating sparse matrix using countvectorizer.

# %%
kkdict = {}

#tokeniszing the dict texts by key
for key in dict1.keys():
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
    tokens = tokenizer.tokenize(str(dict1[key]).lower())  #.lower()
    kkdict[key] = tokens



#mwetokenizer
mwetokenizer = MWETokenizer(meaningful_bigrams)
colloc_t =  dict((tid, mwetokenizer.tokenize(tweet)) for tid,tweet in kkdict.items())
all_words_colloc = list(chain.from_iterable(colloc_t.values()))
colloc_voc = list(set(all_words_colloc))
print(len(colloc_voc))




tids = []
t_words = []
for tid, tokens in colloc_t.items():
    tids.append(tid)
    txt = ' '.join(tokens)
    t_words.append(txt)
    
    
#Countvectorizer
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = "word") 

data_features = vectorizer.fit_transform([' '.join(value) for value in colloc_t.values()])
print (data_features.shape)
# Out:
# 203829
# (81, 198583)

# %% [markdown]
# ## Saving the sparse matrix in a file

# %%
save_file = open("31043313_countVec.txt", 'w')



vocab = vectorizer.get_feature_names()

cx = data_features.tocoo()

#for each dates
for k in tids:
    save_file.write(str(k) + ',')
    
    for i,j,v in list(itertools.zip_longest(cx.row, cx.col, cx.data)): 
        if i == tids.index(k):
            save_file.write(str(j) + ':' + str(v) + ',')
    # removing the extra comma after each iteration
    save_file.seek(0, 2)              
    save_file.seek(save_file.tell() - 1, 0)  
    save_file.truncate()
    save_file.write('\n') # new line for the next date
    
    
save_file.close()

# %%
tids.index('2020-03-22')
# Out:
# 0

# %%
print(colloc_voc[0:6])
# Out:
# ['synthwave', 'dartmouth', 'dvjdougie', 'oald', 'egaovocfcv', 'qvowsd']

# %%
len(pmi_bigrams)
# Out:
# 200

# %% [markdown]
# ## Removing stopwords from vocab

# %%
#removing stopwords from vocab
        
with open("stopwords_en.txt") as stop_words:
    stopwords = stop_words.read().splitlines()

# %%
stopwords[0:6]
# Out:
# ['a', "a's", 'able', 'about', 'above', 'according']

# %%
#filtering the tokens to remove stopwords

filtered_tokenized_words = [token for token in tokenized_words if token not in stopwords]

len(filtered_tokenized_words)
# Out:
# 1244786

# %% [markdown]
# ## Removing tokens with the length less than 3

# %%
# removing tokens with the length less than 3 

len_tokenized_words = [token for token in filtered_tokenized_words if len(token)>=3]

len(len_tokenized_words)
# Out:
# 1194744

# %% [markdown]
# ## Remove context-dependent (with the threshold set to more than 60 days) stop words
#
#
#
# #### Here i had to tokenized once again, so that i have a dictionary with dates and tokenized words for each date

# %%
#context-dependent (with the threshold set to more than 60 days) stop words must be removed from the vocab


#tokenizing by date

new_dict = {}

for key in dict1.keys():
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
    tokens = tokenizer.tokenize(str(dict1[key]).lower())  #.lower()
    new_dict[key] = tokens

# %%
len(new_dict)
# Out:
# 81

# %%
#checking if tokenizing worked

k=0
for i in new_dict.keys():
    k+=len(new_dict[i])
    


k
# Out:
# 2347201

# %% [markdown]
# ## Setting up a dictionary to have only unique tokens for each date

# %%
unique_dict = {}

for key in new_dict.keys():
    unique = list(set(new_dict[key]))
    unique_dict[key] = unique

# %%
#checking if unique dictionary worked

k=0
for i in unique_dict.keys():
    k+=len(unique_dict[i])
    


k
# Out:
# 625505

# %% [markdown]
# ## Putting all the unique token words from each day into a list for the calculation of value counts, which will allow me to account for words which appear in more than 60 days or less than 5 days.

# %%
# putting all the unique words from each day into a list for the calculation of value counts, which will allow me to 
# account of words which appear in more than 60 days and less than 5 days.




# this list has repitions of all unique words in the 81 days
unique_list = []

for key in unique_dict.keys():
    unique_list += unique_dict[key]
    
    
len(unique_list)
# Out:
# 625505

# %% [markdown]
# ## Using the Counter package to make key value pair of unique tokens and their value counts.
#
# ## Here value counts refer to frequency of days the word appear out of 81 days.

# %%
from collections import Counter

counts = Counter(unique_list)
len(counts)
# Out:
# 203649

# %%
counts_dict = dict(counts)
len(counts_dict)
# Out:
# 203649

# %%
import operator
for k,v in sorted(counts_dict.items(), key=operator.itemgetter(1), reverse=True)[:5]:
    print ('key:'+ str(k) + '|','value:' + str(v))
# Out:
# key:care| value:81
# key:american| value:81
# key:families| value:81
# key:already| value:81
# key:she| value:81

# %% [markdown]
# ## These are the context dependant words in a list

# %%
counts_dict = dict(counts)


# these are the context dependant words in a list

context_dep = []
#if value is more than 60, it means that word appeared in more thna 60 days

#afterwards appending the word to context_dep list
for key in counts_dict.keys():
    if counts_dict[key]>60:
        context_dep.append(key)

# %%
context_dep[0:5]
# Out:
# ['care', 'nurses', 'morning', 'game', 'weekend']

# %% [markdown]
# ## These are rare token words in a list

# %%
# these are rare token words in a list

#if value is less than 5, it means that word appeared in less than 5 days and are rare

#afterwards appending the word to rare_words list
rare_words = []

for key in counts_dict.keys():
    if counts_dict[key]<5:
        rare_words.append(key)

# %%
rare_words[0:5]
# Out:
# ['uugcn', 'kvqoq', 'jth', 'snpajnsme', 'quin']

# %%
len(rare_words)
# Out:
# 185627

# %%
len(context_dep)
# Out:
# 1707

# %% [markdown]
# ## This is a list of all the unique words in all the days

# %%
# list of all the unique words in all days

#using set to get unique strings in a list
unique_words = set(unique_list)
unique_words
# Out:
# {'synthwave',
#  'dartmouth',
#  'dvjdougie',
#  'oald',
#  'egaovocfcv',
#  'qvowsd',
#  'publishthescience',
#  'kiba',
#  'shadihamid',
#  'mexixnbeud',
#  'igp',
#  'rpns',
#  'esrfapeogk',
#  'scrubbing',
#  'ohsaasports',
#  'biswajitmohanty',
#  'migrate',
#  'tft',
#  'pandemicdiease',
#  'uhph',
#  'xcllygzahl',
#  'ptimus',
#  'cash-rich',
#  'quin',
#  'arjriz',
#  'sofia',
#  'jwrrizbato',
#  'michto',
#  'tehad',
#  'donorrhea',
#  'rkkddecc',
#  'hathoric',
#  'nbrain-engaging',
#  'onpointsabc',
#  'xba',
#  'abattoirs',
#  'eotuarhoax',
#  'severeacuterespiratorysyndrome',
#  'canvevkkkp',
#  'pnmgdy',
#  'ywawtyocwy',
#  'shithole',
#  'qjcjc',
#  'peternavarro',
#  'azajoxn',
#  'pdx',
#  'uoqgv',
#  'txpzqzwi',
#  'ynidw',
#  'kellyrose',
#  'dermatomyositis',
#  'noahshachtman',
#  'joectrump',
#  'cityofatlanta',
#  'qsdgyam',
#  'tripatriate',
#  'femt',
#  'wjuxotn',
#  'uws',
#  'mzpcd',
#  'hpavpx',
#  'bongs',
#  'wpfq',
#  'ymoowc',
#  'cookingdiary',
#  'bxjhaiay',
#  'csyo',
#  'co-head',
#  'vzezms',
#  'paidleave',
#  'timemanagement',
#  'amdnadajfb',
#  'lys',
#  'cleaver',
#  'lokeshsharma',
#  'opkk',
#  'fibvek',
#  'xaqiijiyey',
#  'renegad',
#  'ixb',
#  'hnuroz',
#  'fahrenthold',
#  'vcoaivlrr',
#  'combustion',
#  'romancemiley',
#  'rij',
#  'rhoads',
#  'govtofkerala',
#  'messy',
#  'tggxhg',
#  'nsamba',
#  'nijfzm',
#  'earlsfieldgirl',
#  'igw',
#  'dkti',
#  'tdp',
#  'mlz',
#  'slsayxl',
#  'wisdom',
#  'ykncr',
#  'kmqj',
#  'sidharthmalhotra',
#  'pdglnowp',
#  'standoutmag',
#  'drjerber',
#  'npeaction',
#  'qrfxynxwfn',
#  'kspvmee',
#  'vta',
#  'tenterrains',
#  'interpreted',
#  'fdlspnbv',
#  'alexandria',
#  'indonesia',
#  'chapel',
#  "world's",
#  'appkrrbkn',
#  'dolq',
#  'npawan',
#  'ihrg',
#  'submerged',
#  'vwldmzbwit',
#  'cedez',
#  'fjz',
#  'irte',
#  'happyisthenewrich',
#  'omnibus',
#  'igaming',
#  'gskkdljuy',
#  'giansagarhospital',
#  'erqsgkq',
#  'blackdeath',
#  'bhamherald',
#  'arsehole',
#  'clo',
#  'chuckgrassley',
#  'propindeye',
#  'jjkwhz',
#  'qipad',
#  'gwyrbrr',
#  'ripper',
#  'desolate',
#  'lordstreetguru',
#  'ifygyywruv',
#  'kpu',
#  'mexicans',
#  'qapyz',
#  'hiqc',
#  'smallbiz',
#  'sse',
#  'trvflfug',
#  'calabrese',
#  'drauqdabhj',
#  'animalwitness',
#  'bkxdxr',
#  'njhgvu',
#  'diamer',
#  'optics',
#  'davidwestin',
#  'lgfdatlfet',
#  'fvi',
#  'vadodara',
#  'gqzfv',
#  'harrasment',
#  'hippie',
#  'zatalks',
#  'mounths',
#  'rmp',
#  'sjs',
#  'dany',
#  'okeyj',
#  'ompcn',
#  'genebsperling',
#  'thestarnews',
#  'uvvjiyeh',
#  'familyguy',
#  'donasi',
#  'dgqq',
#  'itstimeforaction',
#  'beautyinmundane',
#  'deepika',
#  'ikmhy',
#  'kamrup',
#  'youngfocusph',
#  'zptdpx',
#  'uoxifo',
#  'koma',
#  'justsayin',
#  'lvzwestcott',
#  'nans',
#  'yrnnn',
#  'nbrr',
#  'russell',
#  'mers-cov',
#  'evnarvmc',
#  'umvnru',
#  'cips',
#  'frenzied',
#  'rndwmus',
#  'bumblecricket',
#  'basc',
#  'xkbqw',
#  'jayanti',
#  'bmxszx',
#  'apspxqdr',
#  'gwvscvzpbo',
#  'cjxzu',
#  'vpxgjxsern',
#  'morgan',
#  'daykz',
#  'etla',
#  'digitachanges',
#  'hyxzoiascu',
#  'whnszl',
#  'xjkrctadeb',
#  'ncorey',
#  'praecursator',
#  'joan',
#  'pkfwvm',
#  'wmdfx',
#  'publichealthcrisis',
#  'iuaffu',
#  'ckaqadfbu',
#  'manishsnikose',
#  'adln',
#  'mercer',
#  'mrpinkoutloud',
#  'plausable',
#  'andrewlamingmp',
#  'fountains',
#  'screams',
#  'lockdownireland',
#  'krwxzz',
#  'tdhdbimntm',
#  'wgsadkmbw',
#  'never-ending',
#  'ibpleggzky',
#  'adrielhampton',
#  'photoshoot',
#  'gazipur',
#  'kyhddyx',
#  'ubiquitinates',
#  'patrikacoronatruths',
#  'vimvnf',
#  'laevepm',
#  'dalma',
#  'columbialaw',
#  'bwhj',
#  'ntvnews',
#  'ezlcfcsw',
#  'athdzfdw',
#  'scooters',
#  'sansa',
#  'cunts',
#  'xph',
#  'veena',
#  'refindcom',
#  'instahealthnews',
#  'more',
#  'zdhx',
#  'dczz',
#  'mmbhv',
#  'amiri',
#  'bbcnews',
#  'hala',
#  'boze',
#  'razon',
#  'onlineat',
#  'cancelstudentdebt',
#  'kdbyproxy',
#  'bxyitfr',
#  'lrnxd',
#  'scie',
#  'tiresome',
#  'uzsg',
#  'ienns',
#  'nattorney',
#  'waitingforthecall',
#  'obxjen',
#  'norte',
#  'zhao',
#  'ghwxdgm',
#  'zbwb',
#  'bigsalutetodocs',
#  'jens',
#  'xrtsrmn',
#  'bydnhhxad',
#  'yzzvu',
#  'jaweriaabdulqadir',
#  'smrp',
#  'rfreb',
#  'mdsqgyyhl',
#  'fmppa',
#  'reno-tahoe',
#  'ndukmeusd',
#  'btuevpap',
#  'blackmonkyl',
#  'astounds',
#  'edzdghwitn',
#  'ntrumpgopputin',
#  'mhsrip',
#  'iunarjennie',
#  'jbiq',
#  'repointing',
#  'agarwalvineet',
#  'waaah',
#  'nhshkpq',
#  'vdi',
#  'cxczowdv',
#  'scpotjeg',
#  'ozho',
#  'meenakshibalu',
#  'superheroes',
#  'mae',
#  'rxucvlsfjx',
#  'servpro',
#  'uscongress',
#  'ndangerous',
#  'sfszm',
#  'tfyijolx',
#  'nkupwara',
#  'gundy',
#  'ogrg',
#  'crmfgl',
#  'juni',
#  'vacbi',
#  'webtekdigital',
#  'surveillancecapitalism',
#  'supportindia',
#  'pyaksuvm',
#  'archithnews',
#  'keshav',
#  'tnc',
#  'sackkuenssburg',
#  'imw',
#  'pmwyzlc',
#  'bltpy',
#  'anvitsrivastava',
#  'lstnh',
#  'qrfwlnzuhk',
#  'afewpoints',
#  'ffcra',
#  'eesti',
#  'ulrjkkgm',
#  'assamfightscorona',
#  'hatdog',
#  'foxnewsradio',
#  'mindgames',
#  'maanogroup',
#  'klwcr',
#  'aosw',
#  'ejagj',
#  'kdmosgxie',
#  'tuqrzqc',
#  'qrwhlb',
#  'vivrs',
#  'aunvplz',
#  'diyers',
#  'porter',
#  'hadith',
#  'altars',
#  'lxvlkdiol',
#  'bkv',
#  'myxq',
#  'sandwiches',
#  'ineedout',
#  'twnczv',
#  'celia',
#  'fqaphahkmf',
#  'dudm',
#  'dailyupdates',
#  'singhsanjeev',
#  'governing',
#  'naruppukottai',
#  'xiangguoqiu',
#  'memorabilia',
#  'aaay',
#  'vzuu',
#  'spalding',
#  'surgeries',
#  'wyre',
#  'jbba',
#  'brother-in',
#  'kkkonservatives',
#  'atoe',
#  'mwpxai',
#  'modalities',
#  'jclnorghvx',
#  'formely',
#  'ixe',
#  'tmrx',
#  "chhattisgarh's",
#  'nproximity',
#  'tunein',
#  'northerly',
#  'iygffxb',
#  'lwjsa',
#  'womgv',
#  'apot',
#  'dominicwaghorn',
#  'venkykllr',
#  'dffqfkgfmp',
#  'uoccgs',
#  'jhiq',
#  'gaga',
#  'delhipolice',
#  'pumped',
#  'johnismay',
#  'bpyyvyvatf',
#  'gsg',
#  'gjf',
#  'nignorant',
#  'xgfz',
#  'nvcaazog',
#  'qrnwgcq',
#  'qredible',
#  'collectionofpoems',
#  'ruthhecht',
#  'tpxwpgffjz',
#  'gewzcpxvlu',
#  'cvpayne',
#  'academynewc',
#  'qrdtnim',
#  'bnascmpjlu',
#  'zolbt',
#  'manipulative',
#  'idlbeokay',
#  'faller',
#  "n'what",
#  'ping',
#  'turtles',
#  'cwru',
#  'aaronrichterman',
#  'lri',
#  'sundazedrentals',
#  'diakopter',
#  'dess',
#  'pickle',
#  'fmjxdqeg',
#  'fhdytf',
#  'halfords',
#  'rednationrising',
#  'calmingkit',
#  'oiwgf',
#  'ditty',
#  'fancamsareoverparty',
#  'unexplained',
#  'jalali',
#  'kelc',
#  'plyu',
#  'starsuntold',
#  'vtd',
#  'kadapafightscorona',
#  'ndisclaimer',
#  'tcjfhypea',
#  'fixeddeposit',
#  'aestu',
#  'mukerji',
#  'performance',
#  'nrkx',
#  "phe's",
#  'qgwd',
#  'bsimu',
#  'i-t',
#  'gbkvcanvbh',
#  'ipswich',
#  'dawnrlfreeman',
#  'comicstrip',
#  'cipla',
#  'bmdt',
#  'over-reporting',
#  'plx',
#  'kpw',
#  'dotted',
#  'kucrqiedwb',
#  'oygmzi',
#  'dengerous',
#  'fdkipsdley',
#  'kupal',
#  'moonlite',
#  'mlzv',
#  'rkhayc',
#  'imxa',
#  'fcodymiqun',
#  'justmeliberty',
#  'dxyoqxmw',
#  'heros',
#  'two-hour',
#  'otfo',
#  'ftxt',
#  'ffsjin',
#  'sddq',
#  'poxfcnfjoc',
#  'vhele',
#  'contoh',
#  'worldmap',
#  'climbed',
#  'devil',
#  'darnell',
#  'rwde',
#  'vanlathan',
#  'hsdaj',
#  'zbeof',
#  'mayoroflondon',
#  'eympvnpmw',
#  'ylbfci',
#  'fornature',
#  'ipdjkwz',
#  'nexplainer',
#  'kren',
#  'shellzortizz',
#  'ixu',
#  'bailreform',
#  'asteroid',
#  'kxwlu',
#  'drumpt',
#  'rydw',
#  'tlaojlzwxu',
#  'lve',
#  'beschloss',
#  'opzrh',
#  'tayside',
#  'karo',
#  'bazoche',
#  'cyynez',
#  'zftjuyekzf',
#  'syw',
#  'trk',
#  'hdfc',
#  'zlncntdemm',
#  'emnpu',
#  'iampilato',
#  'thenosm',
#  'uysmfg',
#  'detrimental',
#  'mcfrbpxdla',
#  'jsooct',
#  'pfm',
#  'faisalnaifaru',
#  'ewww',
#  'maciej',
#  'aoezqbvqkn',
#  'wjoqjemq',
#  'iusaedqpdg',
#  'reckons',
#  'justintimberlake',
#  'mqiav',
#  'mazishi',
#  'sksjttg',
#  'self-immolation',
#  'iigpil',
#  'ahirwar',
#  'blackbectu',
#  'medicalcare',
#  'toddstarnes',
#  'wroi',
#  'crimelinelaw',
#  'mtnmd',
#  'rwiixaqr',
#  'arghya',
#  'xfxuplardc',
#  'first-time',
#  'feoif',
#  'kcnyjznhnb',
#  'lty',
#  'bastopthinkagain',
#  'abntelugu',
#  'lnp-ipa',
#  'usopen',
#  'mutk',
#  'rllama',
#  'mediapartblogs',
#  'jtfgjz',
#  'nxmkwzr',
#  'pii',
#  'xizr',
#  'zombieland',
#  'mastcyberteam',
#  'designate',
#  'martian',
#  'eblgkmgxm',
#  'hfp',
#  'tributes',
#  'chkanwarpal',
#  'fetdmz',
#  'bc',
#  'reaffirm',
#  'stbvmjc',
#  'paflnrue',
#  'ntcmkh',
#  'youtubelive',
#  'ysnqpl',
#  'xfqla',
#  'tpsjae',
#  'gora',
#  'tomarnold',
#  'flocked',
#  'jfxj',
#  'elite',
#  'cnnsotu',
#  'whbvxbe',
#  'ventilaid',
#  'zzsrpzywx',
#  'ineptitude',
#  'abbott',
#  'recordshoppee',
#  'ffmj',
#  'slaughterhouse',
#  'sevbxzfddy',
#  'wxaeuey',
#  'unhelpfully',
#  'wysopal',
#  'mrsc',
#  'untouched',
#  'trumpdemic',
#  'gitmo',
#  'raymond',
#  'yearofmassdestruction',
#  're-imagine',
#  'hlhbl',
#  'prepareing',
#  'openpeerreview',
#  'intimidate',
#  'consistent',
#  'coronalockwn',
#  'natashabertrand',
#  'standford',
#  'rxnu',
#  'wembdon',
#  'bnd',
#  'kylqbz',
#  'oesapsm',
#  'thedon',
#  'indigos',
#  'widow',
#  'udbq',
#  'kfxzgva',
#  'ulcers',
#  'xrcr',
#  'bedagt',
#  'saxophonist',
#  "giroux's",
#  'rajahrpro',
#  'ypwch',
#  'shiyamaldives',
#  'ybrvix',
#  'fggh',
#  'rosalind',
#  'mikewarrenpiper',
#  'arargroup',
#  "haven't",
#  'africayouth',
#  'lzn',
#  'saifbzayed',
#  'petfoods',
#  'globaldata',
#  'rtseielq',
#  'entities',
#  'cliff',
#  'cyey',
#  'atusheee',
#  'timlackiejr',
#  'arunkr',
#  'rewrite',
#  'd-monogalia',
#  'ynnyhgcfjd',
#  'gfcats',
#  'kyunajhq',
#  'ozei',
#  'tdet',
#  'kyedudd',
#  'apologists',
#  'dgyq',
#  'tklrtohj',
#  'umich',
#  'iottg',
#  'awere',
#  'oyrwe',
#  'ufvko',
#  'jzzkrejldq',
#  'parishpride',
#  'qxcmexbqvw',
#  'igrxlcgm',
#  'jvek',
#  'wtfwhat',
#  'ynk',
#  'autumn',
#  'buses',
#  'heaters',
#  'wiredfreeaccess',
#  'jedbzcq',
#  'stigma',
#  'faithroots',
#  'rjogpal',
#  'coronatestpossitive',
#  'ltsr',
#  'argentine',
#  'czrn',
#  'emzu',
#  'bqaw',
#  'must',
#  'bbcbiasandlies',
#  'drugemporium',
#  'wsgpjjblq',
#  'zjlx',
#  'ndonald',
#  'nadiarace',
#  'epq',
#  'yuzi',
#  'nzzqj',
#  'jonw',
#  'njjurhecbv',
#  'helveticsolar',
#  'soyvizc',
#  'articleeighteen',
#  'mzasrq',
#  'cent',
#  'aws',
#  'nerng',
#  'morningedition',
#  'mrgsut',
#  'logicalindians',
#  'sheconquers',
#  'noz',
#  'indoctrination',
#  'marshallaw',
#  'vali',
#  'kwhlqgi',
#  'outsized',
#  'mqq',
#  'lehrmann',
#  'yjttfb',
#  'khanamjad',
#  'gkblxalkuk',
#  'huj',
#  'jiqedsk',
#  'bhywu',
#  'nascee',
#  'skulfxabdq',
#  'mrjcw',
#  'byoazfkhy',
#  'zouwftgxey',
#  'jackzilla',
#  'brokeuglyboy',
#  'ibwtstmeb',
#  'tew',
#  'dingell',
#  'zixrikuvfz',
#  'cbwz',
#  'gordoncraig',
#  'fortitude',
#  'lecfmie',
#  'qxjgyduqp',
#  'ecoli',
#  'xvm',
#  'techm',
#  'fbpe',
#  'standupwithpete',
#  'bkhkxfxg',
#  'vylbb',
#  'spur',
#  'robertw',
#  'kst',
#  'eventcerdas',
#  'orhan',
#  'litrymanmw',
#  'nmiss',
#  'temporary',
#  'lautner',
#  'misenate',
#  'poddar',
#  'iiism',
#  'kfxwg',
#  'fjt',
#  'npredicting',
#  'madalina',
#  'vegetarian',
#  'mvmi',
#  'aeezg',
#  'connorh',
#  'fro-ing',
#  'pym',
#  'precariousness',
#  'louzjsrh',
#  'brijeshbsingh',
#  'answerable',
#  'thedohertyinst',
#  'jackzhanguk',
#  'ministryofdeath',
#  'unorganised',
#  'micheleromanow',
#  'basu',
#  'surging',
#  'polishaid',
#  'cordwainersgrow',
#  'wlkzn',
#  'qefjndip',
#  'hundredagency',
#  'ndhl',
#  'garry',
#  'nniyang',
#  'conniepersike',
#  'vuaenzpymx',
#  'rulers',
#  'toshy',
#  'defying',
#  'homebuilder',
#  'projectoperaiow',
#  'zgyh',
#  'kathryn',
#  'xfffcpfz',
#  'sqzdil',
#  'tangot',
#  'sanatani',
#  'iutiku',
#  'citybreak',
#  'wardcheck',
#  'uuyhol',
#  'distractionmethod',
#  'tnmirv',
#  'ufkcv',
#  'abounding',
#  'eldkyxj',
#  'bradleysetchell',
#  'natyouthagency',
#  'foxnewskills',
#  'mgkwnwvog',
#  'mtstzi',
#  'stint',
#  'nkbughk',
#  'scbuf',
#  'cyiai',
#  'vhrxkrzc',
#  'lpwz',
#  'gxfw',
#  'ikarcwmiv',
#  'tmklurq',
#  'zcdwx',
#  'omrfm',
#  'rnrflorida',
#  'jennycohn',
#  'malian',
#  'pofjqfq',
#  'pkk',
#  'calgary-south',
#  'fml',
#  'zechariah',
#  'comorbid',
#  'shouts',
#  'mablo',
#  'aictefreeportals',
#  'xyuxm',
#  'magnitude',
#  'ukandeu',
#  'avcpzwoqzf',
#  'tvtm',
#  'qgxdcsb',
#  'vandemataram',
#  'continuingtoserve',
#  'pws',
#  'ifvpprocof',
#  'gmonvyytkq',
#  'nuzzo',
#  'blphilatelic',
#  'opinions',
#  'dogoftheday',
#  'spectacles',
#  'patuli',
#  'yqhyu',
#  'pepsgaff',
#  'mikehardin',
#  'ios',
#  'csyhut',
#  'ngirl',
#  'inclusivecommunication',
#  'marvinsarmy',
#  'gws',
#  'fgp',
#  'leslieoo',
#  'jumla',
#  'ragiing',
#  'fom',
#  'zootonic',
#  'linsey',
#  'blackwater',
#  'bgdailynews',
#  'egct',
#  'zbouharif',
#  'spaceballz',
#  'kgp',
#  'sunnyday',
#  'uliveylgnx',
#  'levitz',
#  'caaphilippines',
#  'ipif',
#  'alistairmilne',
#  'ircu',
#  'pjlhgohjpq',
#  'panics',
#  'gzgrz',
#  'smt',
#  'pzan',
#  'mfx',
#  'jhxsxb',
#  'kolat',
#  'mepratap',
#  'profjimlucey',
#  'ukmfgunite',
#  'checkitout',
#  'beindoor',
#  'gbcq',
#  'stupor',
#  'irrefutable',
#  'bgfynjy',
#  'uziokb',
#  'hydroxide',
#  'aurytotfm',
#  'bgov',
#  'blpg',
#  'naids',
#  'reiyer',
#  'nsh',
#  'morvhhvtt',
#  'iasigw',
#  'rame',
#  'nozt',
#  'fasj',
#  'noxfam',
#  'piigk',
#  'nrestrictions',
#  'davtyj',
#  'jwpetersnyt',
#  'fmzj',
#  'yggit',
#  'jiyhk',
#  'ejceou',
#  'safdarjung',
#  'ajrchfxiqq',
#  'doordash',
#  'finishes',
#  'jweber',
#  'oshdjfr',
#  'selangor',
#  'zyqy',
#  'enea',
#  'iiiiihuuullllllll',
#  'vwj',
#  'lobbyist',
#  'brexitastrophe',
#  'daltonator',
#  'democraticestablishment',
#  'aboriginal',
#  'wun',
#  'rhit',
#  'benet',
#  'irbf',
#  'x-rays',
#  'tldinvestors',
#  'pwkjgbt',
#  'tinz',
#  'drzacharywalker',
#  'kdgf',
#  'algorithm',
#  'raimubruh',
#  'vlyqtl',
#  'jzmirak',
#  'cnph',
#  'elbktymofs',
#  'baqav',
#  'spruce',
#  'fullmetalfinch',
#  'belgrade',
#  'indiasalutescoronawarriors',
#  'spartabeef',
#  'butcherman',
#  'nextending',
#  'yuxrdrszj',
#  'fieo',
#  'jbv',
#  'tilray',
#  'vpfftlo',
#  'aadc',
#  'stfzzv',
#  'pigs',
#  'ybju',
#  'ornge',
#  'uehtzhveg',
#  'hllojuk',
#  'iwzvdoitew',
#  'insides',
#  'thepanda',
#  'ndifference',
#  'roadway',
#  'deaths',
#  'lymphocytes',
#  'silverstoneuk',
#  'hackers',
#  'ncoincidence',
#  'talkingwalk',
#  'anquia',
#  ...}

# %%
len(unique_words)
# Out:
# 203649

# %% [markdown]
# ## Continuing after removing tokens with the length less than 3 step filtering the tokens to remove  context-dependent stopwords

# %%
# continuing after removing tokens with the length less than 3 step

#filtering the tokens to remove  context-dependent stopwords

unique_words = [token for token in unique_words if token not in context_dep]

len(unique_words)
# Out:
# 201942

# %% [markdown]
# ## Filtering the tokens to remove  rare tokens

# %%
#filtering the tokens to remove  rare tokens

unique_words = set(unique_words) - set(rare_words)
unique_words = list(unique_words)

len(unique_words)
# Out:
# 16315

# %% [markdown]
# ## Removing stopwords from vocab

# %%
#removing stopwords from vocab
        
with open("stopwords_en.txt") as stop_words:
    stopwords = stop_words.read().splitlines()
    
#filtering the tokens to remove stopwords

unique_words = [token for token in unique_words if token not in stopwords]





len(unique_words)
# Out:
# 16160

# %% [markdown]
# ## Removing tokens with the length less than 3

# %%
# removing tokens with the length less than 3 

unique_words = [token for token in unique_words if len(token)>=3]
unique_words = list(unique_words)
len(unique_words)


unique_words
# Out:
# ['mec',
#  'televised',
#  'fought',
#  'sagarikaghose',
#  'saviour',
#  'regulated',
#  'gravitas',
#  'shouting',
#  'abe',
#  'pmp',
#  'melissa',
#  'debit',
#  'venturecapital',
#  'titans',
#  'calendar',
#  'chiefs',
#  'envisaged',
#  'grip',
#  'reducing',
#  'danawhite',
#  'dfid',
#  'hardware',
#  'worldhealthorganization',
#  'proximity',
#  'smiles',
#  'inquiry',
#  'apex',
#  'trendingnews',
#  'understatement',
#  'stone',
#  'shithole',
#  'repair',
#  'majeure',
#  'clarified',
#  'go-to',
#  'cambridge',
#  'advises',
#  'scapegoating',
#  'eastafrica',
#  'newsfeed',
#  'breaches',
#  'provinces',
#  'parker',
#  'roles',
#  'swamy',
#  'princess',
#  'identified',
#  'chinas',
#  'philanthropist',
#  'unknowingly',
#  'cream',
#  'dey',
#  'banana',
#  'modeling',
#  'wallace',
#  'agp',
#  'ailing',
#  'fastest-growing',
#  'disproportionately',
#  'incl',
#  'prevail',
#  'eddie',
#  'pharmacists',
#  'coronavirusnews',
#  'resulting',
#  'chicken',
#  'brotherhood',
#  'wee',
#  'ambassadors',
#  'garbage',
#  'nightmare',
#  'tuesday',
#  'nlatest',
#  'ant',
#  'empathetic',
#  'superspreaders',
#  'classed',
#  'rmf',
#  'inept',
#  'clowns',
#  'zeenews',
#  'chi',
#  'cornwall',
#  'containers',
#  'wisdom',
#  'danrather',
#  'wont',
#  'academic',
#  'resign',
#  'fee',
#  'impeachment',
#  'bros',
#  'referring',
#  'assured',
#  'roi',
#  'catches',
#  'ikea',
#  'lfc',
#  'giat',
#  'sap',
#  'indonesia',
#  "world's",
#  'gojoe',
#  'streaming',
#  'pentagon',
#  'framing',
#  'austria',
#  'editor',
#  'submitted',
#  'behalf',
#  'packet',
#  'approaching',
#  'aba',
#  'portray',
#  'npresident',
#  'dokpesi',
#  'tribe',
#  'lgu',
#  'clueless',
#  'ndiscover',
#  'grounded',
#  'vijayan',
#  'offguardian',
#  'suggest',
#  'vip',
#  'candle',
#  'sayin',
#  'nudge',
#  'chuckgrassley',
#  'flooding',
#  'bump',
#  'mda',
#  'curse',
#  'swap',
#  'oprah',
#  'duke',
#  'jajpur',
#  'vjv',
#  'devastation',
#  'leap',
#  'haters',
#  'confinement',
#  'mexicans',
#  'websites',
#  'smallbiz',
#  'follow-up',
#  "friday's",
#  'ana',
#  'conclusions',
#  'govstitt',
#  'ins',
#  'optics',
#  'mumbaimirror',
#  'discarded',
#  'radical',
#  'executing',
#  'block',
#  'web',
#  'vadodara',
#  'adm',
#  'ooni',
#  'pizza',
#  'inspiration',
#  'noted',
#  'conclusion',
#  'verbal',
#  'mbs',
#  'executive',
#  'udl',
#  'ppenow',
#  'tiananmen',
#  'constituency',
#  'gavinwilliamson',
#  'territory',
#  'prouder',
#  'yaba',
#  'noyo',
#  'coronavirus-induced',
#  'scomo',
#  'crops',
#  'hospices',
#  'teampelosi',
#  'romney',
#  'del',
#  'sympathy',
#  'pds',
#  'analyzing',
#  'nthousands',
#  'starmer',
#  'intake',
#  'dwellers',
#  'backup',
#  'diy',
#  'religious',
#  'acosta',
#  'intellectual',
#  'nzd',
#  'costco',
#  'wished',
#  'zone',
#  'deceived',
#  'withheld',
#  'russell',
#  'strongertogether',
#  'served',
#  'arms',
#  'defy',
#  'inclusive',
#  'visited',
#  'pork',
#  'revisit',
#  'patel',
#  'seat',
#  'integrated',
#  'exponentially',
#  'cremate',
#  'morgan',
#  'obesity',
#  'deprived',
#  'anjanaomkashyap',
#  'chase',
#  'muscle',
#  'campbellclaret',
#  'await',
#  'mjalshrika',
#  'laughable',
#  'timed',
#  'joan',
#  'jogging',
#  'decades',
#  'somalia',
#  'poster',
#  'competent',
#  'jumped',
#  'controversy',
#  'nycgov',
#  'jokes',
#  'extensive',
#  'rdc',
#  'necessities',
#  'covidresponse',
#  'screams',
#  'hmmmm',
#  'bruh',
#  'mirrors',
#  'injured',
#  'rituals',
#  'organizing',
#  'pensioner',
#  'pleasant',
#  'foot',
#  'shamelessly',
#  'mushroom',
#  'evicted',
#  'secondary',
#  'tel',
#  'restriction',
#  'casts',
#  'molly',
#  'resistance',
#  'virginia',
#  'liberia',
#  'palestine',
#  'bleach',
#  'breast',
#  'magas',
#  'muh',
#  'enhancing',
#  'impossible',
#  'soviet',
#  'provision',
#  'framework',
#  'cunts',
#  'park',
#  'meghan',
#  'iam',
#  'sia',
#  'tutoring',
#  'yaar',
#  'greatly',
#  'dispatches',
#  'tweeted',
#  'watches',
#  'precaution',
#  'abia',
#  'dodging',
#  'ngovt',
#  'hungry',
#  'pieces',
#  'yomequedoencasa',
#  'scottgottliebmd',
#  "england's",
#  'jackson',
#  'tuesdayvibes',
#  'metaphors',
#  'waves',
#  'balloon',
#  'citizenship',
#  'surprises',
#  'nbelgium',
#  'sunrise',
#  'foolishness',
#  'husbands',
#  'wks',
#  'shaun',
#  'navigate',
#  'cerb',
#  'isolated',
#  'securities',
#  'october',
#  'prix',
#  'administrative',
#  'scenarios',
#  'slay',
#  'questionable',
#  'unfair',
#  'musicians',
#  'julia',
#  'hallelujah',
#  'knee',
#  'louisville',
#  'severely',
#  'enhance',
#  'bdo',
#  'nfollow',
#  'contradictory',
#  'contact-tracing',
#  'infosys',
#  'halt',
#  'emerges',
#  'rod',
#  'realm',
#  'masses',
#  'enclosed',
#  'sentinel',
#  'boxer',
#  'desert',
#  'superheroes',
#  'sociopath',
#  'drums',
#  'cjwerleman',
#  'adam',
#  'collapsed',
#  'globalpandemic',
#  'mobilized',
#  'cultures',
#  'tweeting',
#  'chhattisgarh',
#  'thbewithyou',
#  'methodology',
#  'auv',
#  'co-operation',
#  'neveryone',
#  'cyclists',
#  'notifications',
#  'merger',
#  'supplier',
#  'associate',
#  'toryliescostlives',
#  'minnesota',
#  'drives',
#  'harry',
#  'senseless',
#  'maddow',
#  'shouldnt',
#  'angeles',
#  'budget',
#  'booth',
#  'biko',
#  'conducted',
#  'globalcitizen',
#  'recycling',
#  'randomly',
#  'crosses',
#  'fck',
#  'necessarily',
#  'apocalyptic',
#  'delicious',
#  'intentions',
#  'certainty',
#  'frontlineworkers',
#  'fundraising',
#  'neverforget',
#  'edmonton',
#  'secpompeo',
#  'dengue',
#  'systematic',
#  'angelarayner',
#  'units',
#  'curfews',
#  'imperialcollege',
#  'communications',
#  'kanika',
#  'remembered',
#  'automatically',
#  'backwards',
#  'cabinet',
#  'ruleoflaw',
#  'tyson',
#  'governing',
#  'subsequent',
#  'cpr',
#  'biotechnology',
#  'detected',
#  'cuba',
#  'regions',
#  'surgeries',
#  'hacker',
#  'senkamalaharris',
#  'repmattgaetz',
#  'nnamdi',
#  'archive',
#  'eaj',
#  'helen',
#  'sendavidperdue',
#  'subscribe',
#  'nover',
#  'lockdownsa',
#  'determinants',
#  'lsmoh',
#  'rover',
#  'boyfriend',
#  'interpretation',
#  'gradually',
#  'coronamemes',
#  'dependent',
#  'fawadchaudhry',
#  'cyclones',
#  'wrestling',
#  'lessen',
#  'askdrh',
#  'coronaviruschina',
#  'cumbria',
#  'sane',
#  'tes',
#  'gaga',
#  'vet',
#  'delhipolice',
#  'transatlantic',
#  'jump',
#  'juicy',
#  'barred',
#  'moron',
#  'bloom',
#  'symbolic',
#  'gloucestershire',
#  'repayment',
#  'cold',
#  'pasta',
#  'navin',
#  'unlimited',
#  'urges',
#  'characters',
#  'tissues',
#  'dis',
#  'treatments',
#  'jigawa',
#  'skip',
#  'weapon',
#  'cancellation',
#  'hpe',
#  'nnational',
#  'theellenshow',
#  'aug',
#  'successful',
#  'dog',
#  'wmd',
#  'welfare',
#  'lowered',
#  'listened',
#  'rudygiuliani',
#  'globe',
#  'representing',
#  'personalities',
#  'confident',
#  'bins',
#  'grid',
#  'ping',
#  'aging',
#  'stresses',
#  'accountability',
#  'asu',
#  'threaten',
#  'public-health',
#  'talented',
#  'bailout',
#  'attendant',
#  'retaliation',
#  'puerto',
#  'sections',
#  'charliekirk',
#  'clout',
#  'academy',
#  'ncov',
#  'exist',
#  'astrazeneca',
#  'jee',
#  'masstestingnowph',
#  'boko',
#  'corps',
#  'circles',
#  'visa',
#  'performance',
#  'hotspot',
#  'cooperating',
#  'laughing',
#  'preferred',
#  'warrington',
#  'patents',
#  'aja',
#  'waived',
#  'bazar',
#  'allocation',
#  'predicting',
#  'affair',
#  'googlenews',
#  'fitted',
#  'plx',
#  'destroying',
#  'fuel',
#  'depts',
#  'dci',
#  'climatechange',
#  'cope',
#  'resisted',
#  'coast',
#  'sewage',
#  'frozen',
#  'resulted',
#  'comedy',
#  'cared',
#  'congrats',
#  'annual',
#  'tackling',
#  'apologise',
#  'heros',
#  'reassess',
#  'males',
#  'neet',
#  'worstpresidentever',
#  'brands',
#  'cet',
#  'govrondesantis',
#  'troubling',
#  'grifter',
#  'antiviral',
#  'lvd',
#  'advocates',
#  'neil',
#  'tactic',
#  'maximize',
#  'climbed',
#  'supremecourt',
#  'informative',
#  'devil',
#  'thamendmentnow',
#  'conquer',
#  'usrc',
#  'hcq',
#  'abuja',
#  'variable',
#  'avoiding',
#  'overwhelming',
#  'skin',
#  'enquiries',
#  'trumphasnoplan',
#  'sellers',
#  'mayoroflondon',
#  'agency',
#  'rashtrapatibhvn',
#  'dpradhanbjp',
#  'teaches',
#  'xxx',
#  'throw',
#  'cinemas',
#  'aloksharma',
#  'communalism',
#  'secured',
#  'aaas',
#  'dtmag',
#  'pinch',
#  'src',
#  'mosque',
#  'technologies',
#  'goldman',
#  'efficient',
#  'unequal',
#  'honeymoon',
#  'promo',
#  'ccot',
#  'nhsheroes',
#  'webpage',
#  'leavenoonebehind',
#  'acquire',
#  'luck',
#  'guiding',
#  'labor',
#  'subject',
#  'complained',
#  'eligibility',
#  'reece',
#  'veritas',
#  'karo',
#  'hdfc',
#  'argument',
#  'econ',
#  'graphical',
#  'announce',
#  'jacinda',
#  'laborers',
#  'detrimental',
#  'gdp',
#  'wifi',
#  'participant',
#  'ancient',
#  'suggesting',
#  'ser',
#  'mombasa',
#  'mouths',
#  'comparing',
#  'jewelry',
#  "country's",
#  'beautifully',
#  'politician',
#  'keeper',
#  'trumpdeathtoll',
#  'jim',
#  'transplant',
#  'myths',
#  'chosen',
#  'boredom',
#  'finest',
#  'idps',
#  'tricks',
#  'android',
#  'nonce',
#  'coalition',
#  'rifle',
#  'mounting',
#  'vanonselenp',
#  'bhi',
#  'ssp',
#  'forecasting',
#  'fit',
#  'attributed',
#  'erdogan',
#  'hubs',
#  'observed',
#  'wot',
#  'shelter',
#  'interiordesign',
#  'daylockdown',
#  'cyrilramaphosa',
#  'succeed',
#  'pills',
#  'gross',
#  'asleep',
#  'arrives',
#  'respite',
#  'odu',
#  'raha',
#  'soundcloud',
#  'record-breaking',
#  'sacks',
#  'exhibiting',
#  'shld',
#  'reservation',
#  'faulty',
#  'rabbit',
#  'tributes',
#  'coronavirusuk',
#  'norms',
#  'offers',
#  'spam',
#  'applicants',
#  'tolerance',
#  'thismorning',
#  'talent',
#  'bookings',
#  'repeated',
#  'ain',
#  'simplicity',
#  'replies',
#  'adhanom',
#  'torygenocide',
#  'psa',
#  'africacdc',
#  'minimizing',
#  'adequate',
#  'bubbles',
#  'invention',
#  'nlg',
#  'rebellion',
#  'elite',
#  'oncology',
#  'fwd',
#  'pound',
#  'reparations',
#  'rdt',
#  'ineptitude',
#  'vatican',
#  'mon',
#  'abbott',
#  'hydroxy',
#  'blr',
#  'swedes',
#  'complicated',
#  'reelection',
#  'guessing',
#  'wetherspoons',
#  'composition',
#  'nnews',
#  'coherent',
#  'rwanda',
#  'slowly',
#  'plant-based',
#  'pantries',
#  'npassword',
#  'officer',
#  'iiot',
#  'mines',
#  'addressed',
#  'strongmen',
#  'billboard',
#  'raymond',
#  'raises',
#  'ycp',
#  'couch',
#  'consistent',
#  'debunks',
#  'spraying',
#  'businesscontinuity',
#  'twist',
#  'barry',
#  'lit',
#  'indoors',
#  'widow',
#  'robertalai',
#  'drrpnishank',
#  'perceptions',
#  'risky',
#  'on-going',
#  'cup',
#  'links',
#  'ondo',
#  'assessed',
#  'stimuluscheck',
#  'safest',
#  'harm',
#  'vegas',
#  'one-third',
#  'csir',
#  'wireless',
#  'prod',
#  'connected',
#  'pendamic',
#  'chinamustexplain',
#  'layoffs',
#  'bcpoli',
#  'entertainment',
#  'quarantining',
#  'politicising',
#  'entities',
#  'cliff',
#  'lobbying',
#  'lanes',
#  'nnext',
#  'wales',
#  'escalates',
#  'herald',
#  'thanking',
#  'iit',
#  'vacation',
#  'rewrite',
#  'rathee',
#  'holding',
#  'involved',
#  'modiji',
#  'apologises',
#  'batteries',
#  'organic',
#  'ncan',
#  'locally',
#  'winding',
#  'wary',
#  'weserveandprotect',
#  'commodity',
#  'las',
#  'hormones',
#  'ndont',
#  'fuckers',
#  'escalate',
#  'gendered',
#  'logged',
#  'requirements',
#  'conway',
#  'sebi',
#  'sao',
#  'tab',
#  'smes',
#  'autumn',
#  'buses',
#  'sme',
#  'babetrayal',
#  'corner',
#  'stigma',
#  'nicotine',
#  'wouldnt',
#  'mistake',
#  'powered',
#  'quarantineandchill',
#  'purevpn',
#  'supplement',
#  'messenger',
#  'complicit',
#  'approving',
#  'stage',
#  'exploring',
#  'multi',
#  'chilling',
#  'poi',
#  'isle',
#  'westandwithitaly',
#  'ndonald',
#  'ncp',
#  'dropped',
#  'rolled',
#  'delusional',
#  'hussein',
#  'nominate',
#  'nworld',
#  'abiding',
#  'caves',
#  'nahin',
#  'swarms',
#  'bull',
#  'epc',
#  'webinars',
#  'truckers',
#  'cent',
#  "whitmer's",
#  'donatewithoutspending',
#  'nfl',
#  'fossil',
#  'failures',
#  'implies',
#  'selfisolation',
#  'strengthening',
#  'indoctrination',
#  'mannkibaat',
#  'experiences',
#  'tamil',
#  'combine',
#  'patent',
#  'compromised',
#  'hometown',
#  'defensive',
#  'scott',
#  'noticias',
#  'gathered',
#  'irrelevant',
#  'wipe',
#  'gavinnewsom',
#  'eager',
#  'pensioners',
#  'tol',
#  'disabled',
#  'cpho',
#  'nto',
#  'chatting',
#  'bang',
#  'substitute',
#  'imperative',
#  'alpha',
#  'cronies',
#  'champ',
#  'lewis',
#  'queues',
#  'forever',
#  'rating',
#  'fbpe',
#  'consequences',
#  'habit',
#  'combo',
#  'dollar',
#  'metre',
#  'walkers',
#  'spur',
#  'njohnson',
#  'economical',
#  'overwhelmed',
#  'investigation',
#  'nlisten',
#  'temporary',
#  'fixed',
#  'orchestra',
#  'femi',
#  'mercy',
#  'skye',
#  'nhey',
#  'unlocking',
#  'venmo',
#  'telecoms',
#  'witnessed',
#  'taekook',
#  'high-risk',
#  'timesofindia',
#  'subjected',
#  'niv',
#  'hoped',
#  'cps',
#  'judged',
#  'joncoopertweets',
#  'fame',
#  'indonesian',
#  'vegetarian',
#  'comprehensive',
#  'samples',
#  'diarrhoea',
#  'ken',
#  'creatives',
#  'delay',
#  'script',
#  'pandemi',
#  'mumbaipolice',
#  'bloody',
#  'bribe',
#  'culprits',
#  'overwhelmingly',
#  'miles',
#  'opsoms',
#  'injected',
#  'intensity',
#  'mlg',
#  'hmoindia',
#  'ramadhan',
#  'supplying',
#  'crimson',
#  'isc',
#  'zxr',
#  'pathways',
#  'hustle',
#  'surging',
#  'peel',
#  'subscription',
#  'ngrpresident',
#  'unexpected',
#  'reallyswara',
#  'usd',
#  'warp',
#  'ndespite',
#  'arnab',
#  'amended',
#  'lingering',
#  'oral',
#  'guangzhou',
#  'sai',
#  'resumes',
#  'sciences',
#  'sow',
#  'oooh',
#  'rulers',
#  'mothers',
#  'toe',
#  'defying',
#  'briefly',
#  'morocco',
#  'colour',
#  'busters',
#  'kid',
#  'ntopic',
#  'fav',
#  'bureaucrats',
#  "nwhat's",
#  'kellyannepolls',
#  'thailand',
#  'gulf',
#  'racing',
#  'georgeflyod',
#  'renamed',
#  'overtakes',
#  'seventeen',
#  'operates',
#  'pillow',
#  'industrial',
#  'mild',
#  'proportion',
#  'pissed',
#  'settlement',
#  'riots',
#  'vessels',
#  'evangelists',
#  'tryna',
#  'obligations',
#  'facemasks',
#  'cont',
#  'strategically',
#  'protester',
#  'participants',
#  'arteta',
#  ...]

# %%
unique_words
len(unique_words)
# Out:
# 15572

# %%
unique_words
# Out:
# ['mec',
#  'televised',
#  'fought',
#  'sagarikaghose',
#  'saviour',
#  'regulated',
#  'gravitas',
#  'shouting',
#  'abe',
#  'pmp',
#  'melissa',
#  'debit',
#  'venturecapital',
#  'titans',
#  'calendar',
#  'chiefs',
#  'envisaged',
#  'grip',
#  'reducing',
#  'danawhite',
#  'dfid',
#  'hardware',
#  'worldhealthorganization',
#  'proximity',
#  'smiles',
#  'inquiry',
#  'apex',
#  'trendingnews',
#  'understatement',
#  'stone',
#  'shithole',
#  'repair',
#  'majeure',
#  'clarified',
#  'go-to',
#  'cambridge',
#  'advises',
#  'scapegoating',
#  'eastafrica',
#  'newsfeed',
#  'breaches',
#  'provinces',
#  'parker',
#  'roles',
#  'swamy',
#  'princess',
#  'identified',
#  'chinas',
#  'philanthropist',
#  'unknowingly',
#  'cream',
#  'dey',
#  'banana',
#  'modeling',
#  'wallace',
#  'agp',
#  'ailing',
#  'fastest-growing',
#  'disproportionately',
#  'incl',
#  'prevail',
#  'eddie',
#  'pharmacists',
#  'coronavirusnews',
#  'resulting',
#  'chicken',
#  'brotherhood',
#  'wee',
#  'ambassadors',
#  'garbage',
#  'nightmare',
#  'tuesday',
#  'nlatest',
#  'ant',
#  'empathetic',
#  'superspreaders',
#  'classed',
#  'rmf',
#  'inept',
#  'clowns',
#  'zeenews',
#  'chi',
#  'cornwall',
#  'containers',
#  'wisdom',
#  'danrather',
#  'wont',
#  'academic',
#  'resign',
#  'fee',
#  'impeachment',
#  'bros',
#  'referring',
#  'assured',
#  'roi',
#  'catches',
#  'ikea',
#  'lfc',
#  'giat',
#  'sap',
#  'indonesia',
#  "world's",
#  'gojoe',
#  'streaming',
#  'pentagon',
#  'framing',
#  'austria',
#  'editor',
#  'submitted',
#  'behalf',
#  'packet',
#  'approaching',
#  'aba',
#  'portray',
#  'npresident',
#  'dokpesi',
#  'tribe',
#  'lgu',
#  'clueless',
#  'ndiscover',
#  'grounded',
#  'vijayan',
#  'offguardian',
#  'suggest',
#  'vip',
#  'candle',
#  'sayin',
#  'nudge',
#  'chuckgrassley',
#  'flooding',
#  'bump',
#  'mda',
#  'curse',
#  'swap',
#  'oprah',
#  'duke',
#  'jajpur',
#  'vjv',
#  'devastation',
#  'leap',
#  'haters',
#  'confinement',
#  'mexicans',
#  'websites',
#  'smallbiz',
#  'follow-up',
#  "friday's",
#  'ana',
#  'conclusions',
#  'govstitt',
#  'ins',
#  'optics',
#  'mumbaimirror',
#  'discarded',
#  'radical',
#  'executing',
#  'block',
#  'web',
#  'vadodara',
#  'adm',
#  'ooni',
#  'pizza',
#  'inspiration',
#  'noted',
#  'conclusion',
#  'verbal',
#  'mbs',
#  'executive',
#  'udl',
#  'ppenow',
#  'tiananmen',
#  'constituency',
#  'gavinwilliamson',
#  'territory',
#  'prouder',
#  'yaba',
#  'noyo',
#  'coronavirus-induced',
#  'scomo',
#  'crops',
#  'hospices',
#  'teampelosi',
#  'romney',
#  'del',
#  'sympathy',
#  'pds',
#  'analyzing',
#  'nthousands',
#  'starmer',
#  'intake',
#  'dwellers',
#  'backup',
#  'diy',
#  'religious',
#  'acosta',
#  'intellectual',
#  'nzd',
#  'costco',
#  'wished',
#  'zone',
#  'deceived',
#  'withheld',
#  'russell',
#  'strongertogether',
#  'served',
#  'arms',
#  'defy',
#  'inclusive',
#  'visited',
#  'pork',
#  'revisit',
#  'patel',
#  'seat',
#  'integrated',
#  'exponentially',
#  'cremate',
#  'morgan',
#  'obesity',
#  'deprived',
#  'anjanaomkashyap',
#  'chase',
#  'muscle',
#  'campbellclaret',
#  'await',
#  'mjalshrika',
#  'laughable',
#  'timed',
#  'joan',
#  'jogging',
#  'decades',
#  'somalia',
#  'poster',
#  'competent',
#  'jumped',
#  'controversy',
#  'nycgov',
#  'jokes',
#  'extensive',
#  'rdc',
#  'necessities',
#  'covidresponse',
#  'screams',
#  'hmmmm',
#  'bruh',
#  'mirrors',
#  'injured',
#  'rituals',
#  'organizing',
#  'pensioner',
#  'pleasant',
#  'foot',
#  'shamelessly',
#  'mushroom',
#  'evicted',
#  'secondary',
#  'tel',
#  'restriction',
#  'casts',
#  'molly',
#  'resistance',
#  'virginia',
#  'liberia',
#  'palestine',
#  'bleach',
#  'breast',
#  'magas',
#  'muh',
#  'enhancing',
#  'impossible',
#  'soviet',
#  'provision',
#  'framework',
#  'cunts',
#  'park',
#  'meghan',
#  'iam',
#  'sia',
#  'tutoring',
#  'yaar',
#  'greatly',
#  'dispatches',
#  'tweeted',
#  'watches',
#  'precaution',
#  'abia',
#  'dodging',
#  'ngovt',
#  'hungry',
#  'pieces',
#  'yomequedoencasa',
#  'scottgottliebmd',
#  "england's",
#  'jackson',
#  'tuesdayvibes',
#  'metaphors',
#  'waves',
#  'balloon',
#  'citizenship',
#  'surprises',
#  'nbelgium',
#  'sunrise',
#  'foolishness',
#  'husbands',
#  'wks',
#  'shaun',
#  'navigate',
#  'cerb',
#  'isolated',
#  'securities',
#  'october',
#  'prix',
#  'administrative',
#  'scenarios',
#  'slay',
#  'questionable',
#  'unfair',
#  'musicians',
#  'julia',
#  'hallelujah',
#  'knee',
#  'louisville',
#  'severely',
#  'enhance',
#  'bdo',
#  'nfollow',
#  'contradictory',
#  'contact-tracing',
#  'infosys',
#  'halt',
#  'emerges',
#  'rod',
#  'realm',
#  'masses',
#  'enclosed',
#  'sentinel',
#  'boxer',
#  'desert',
#  'superheroes',
#  'sociopath',
#  'drums',
#  'cjwerleman',
#  'adam',
#  'collapsed',
#  'globalpandemic',
#  'mobilized',
#  'cultures',
#  'tweeting',
#  'chhattisgarh',
#  'thbewithyou',
#  'methodology',
#  'auv',
#  'co-operation',
#  'neveryone',
#  'cyclists',
#  'notifications',
#  'merger',
#  'supplier',
#  'associate',
#  'toryliescostlives',
#  'minnesota',
#  'drives',
#  'harry',
#  'senseless',
#  'maddow',
#  'shouldnt',
#  'angeles',
#  'budget',
#  'booth',
#  'biko',
#  'conducted',
#  'globalcitizen',
#  'recycling',
#  'randomly',
#  'crosses',
#  'fck',
#  'necessarily',
#  'apocalyptic',
#  'delicious',
#  'intentions',
#  'certainty',
#  'frontlineworkers',
#  'fundraising',
#  'neverforget',
#  'edmonton',
#  'secpompeo',
#  'dengue',
#  'systematic',
#  'angelarayner',
#  'units',
#  'curfews',
#  'imperialcollege',
#  'communications',
#  'kanika',
#  'remembered',
#  'automatically',
#  'backwards',
#  'cabinet',
#  'ruleoflaw',
#  'tyson',
#  'governing',
#  'subsequent',
#  'cpr',
#  'biotechnology',
#  'detected',
#  'cuba',
#  'regions',
#  'surgeries',
#  'hacker',
#  'senkamalaharris',
#  'repmattgaetz',
#  'nnamdi',
#  'archive',
#  'eaj',
#  'helen',
#  'sendavidperdue',
#  'subscribe',
#  'nover',
#  'lockdownsa',
#  'determinants',
#  'lsmoh',
#  'rover',
#  'boyfriend',
#  'interpretation',
#  'gradually',
#  'coronamemes',
#  'dependent',
#  'fawadchaudhry',
#  'cyclones',
#  'wrestling',
#  'lessen',
#  'askdrh',
#  'coronaviruschina',
#  'cumbria',
#  'sane',
#  'tes',
#  'gaga',
#  'vet',
#  'delhipolice',
#  'transatlantic',
#  'jump',
#  'juicy',
#  'barred',
#  'moron',
#  'bloom',
#  'symbolic',
#  'gloucestershire',
#  'repayment',
#  'cold',
#  'pasta',
#  'navin',
#  'unlimited',
#  'urges',
#  'characters',
#  'tissues',
#  'dis',
#  'treatments',
#  'jigawa',
#  'skip',
#  'weapon',
#  'cancellation',
#  'hpe',
#  'nnational',
#  'theellenshow',
#  'aug',
#  'successful',
#  'dog',
#  'wmd',
#  'welfare',
#  'lowered',
#  'listened',
#  'rudygiuliani',
#  'globe',
#  'representing',
#  'personalities',
#  'confident',
#  'bins',
#  'grid',
#  'ping',
#  'aging',
#  'stresses',
#  'accountability',
#  'asu',
#  'threaten',
#  'public-health',
#  'talented',
#  'bailout',
#  'attendant',
#  'retaliation',
#  'puerto',
#  'sections',
#  'charliekirk',
#  'clout',
#  'academy',
#  'ncov',
#  'exist',
#  'astrazeneca',
#  'jee',
#  'masstestingnowph',
#  'boko',
#  'corps',
#  'circles',
#  'visa',
#  'performance',
#  'hotspot',
#  'cooperating',
#  'laughing',
#  'preferred',
#  'warrington',
#  'patents',
#  'aja',
#  'waived',
#  'bazar',
#  'allocation',
#  'predicting',
#  'affair',
#  'googlenews',
#  'fitted',
#  'plx',
#  'destroying',
#  'fuel',
#  'depts',
#  'dci',
#  'climatechange',
#  'cope',
#  'resisted',
#  'coast',
#  'sewage',
#  'frozen',
#  'resulted',
#  'comedy',
#  'cared',
#  'congrats',
#  'annual',
#  'tackling',
#  'apologise',
#  'heros',
#  'reassess',
#  'males',
#  'neet',
#  'worstpresidentever',
#  'brands',
#  'cet',
#  'govrondesantis',
#  'troubling',
#  'grifter',
#  'antiviral',
#  'lvd',
#  'advocates',
#  'neil',
#  'tactic',
#  'maximize',
#  'climbed',
#  'supremecourt',
#  'informative',
#  'devil',
#  'thamendmentnow',
#  'conquer',
#  'usrc',
#  'hcq',
#  'abuja',
#  'variable',
#  'avoiding',
#  'overwhelming',
#  'skin',
#  'enquiries',
#  'trumphasnoplan',
#  'sellers',
#  'mayoroflondon',
#  'agency',
#  'rashtrapatibhvn',
#  'dpradhanbjp',
#  'teaches',
#  'xxx',
#  'throw',
#  'cinemas',
#  'aloksharma',
#  'communalism',
#  'secured',
#  'aaas',
#  'dtmag',
#  'pinch',
#  'src',
#  'mosque',
#  'technologies',
#  'goldman',
#  'efficient',
#  'unequal',
#  'honeymoon',
#  'promo',
#  'ccot',
#  'nhsheroes',
#  'webpage',
#  'leavenoonebehind',
#  'acquire',
#  'luck',
#  'guiding',
#  'labor',
#  'subject',
#  'complained',
#  'eligibility',
#  'reece',
#  'veritas',
#  'karo',
#  'hdfc',
#  'argument',
#  'econ',
#  'graphical',
#  'announce',
#  'jacinda',
#  'laborers',
#  'detrimental',
#  'gdp',
#  'wifi',
#  'participant',
#  'ancient',
#  'suggesting',
#  'ser',
#  'mombasa',
#  'mouths',
#  'comparing',
#  'jewelry',
#  "country's",
#  'beautifully',
#  'politician',
#  'keeper',
#  'trumpdeathtoll',
#  'jim',
#  'transplant',
#  'myths',
#  'chosen',
#  'boredom',
#  'finest',
#  'idps',
#  'tricks',
#  'android',
#  'nonce',
#  'coalition',
#  'rifle',
#  'mounting',
#  'vanonselenp',
#  'bhi',
#  'ssp',
#  'forecasting',
#  'fit',
#  'attributed',
#  'erdogan',
#  'hubs',
#  'observed',
#  'wot',
#  'shelter',
#  'interiordesign',
#  'daylockdown',
#  'cyrilramaphosa',
#  'succeed',
#  'pills',
#  'gross',
#  'asleep',
#  'arrives',
#  'respite',
#  'odu',
#  'raha',
#  'soundcloud',
#  'record-breaking',
#  'sacks',
#  'exhibiting',
#  'shld',
#  'reservation',
#  'faulty',
#  'rabbit',
#  'tributes',
#  'coronavirusuk',
#  'norms',
#  'offers',
#  'spam',
#  'applicants',
#  'tolerance',
#  'thismorning',
#  'talent',
#  'bookings',
#  'repeated',
#  'ain',
#  'simplicity',
#  'replies',
#  'adhanom',
#  'torygenocide',
#  'psa',
#  'africacdc',
#  'minimizing',
#  'adequate',
#  'bubbles',
#  'invention',
#  'nlg',
#  'rebellion',
#  'elite',
#  'oncology',
#  'fwd',
#  'pound',
#  'reparations',
#  'rdt',
#  'ineptitude',
#  'vatican',
#  'mon',
#  'abbott',
#  'hydroxy',
#  'blr',
#  'swedes',
#  'complicated',
#  'reelection',
#  'guessing',
#  'wetherspoons',
#  'composition',
#  'nnews',
#  'coherent',
#  'rwanda',
#  'slowly',
#  'plant-based',
#  'pantries',
#  'npassword',
#  'officer',
#  'iiot',
#  'mines',
#  'addressed',
#  'strongmen',
#  'billboard',
#  'raymond',
#  'raises',
#  'ycp',
#  'couch',
#  'consistent',
#  'debunks',
#  'spraying',
#  'businesscontinuity',
#  'twist',
#  'barry',
#  'lit',
#  'indoors',
#  'widow',
#  'robertalai',
#  'drrpnishank',
#  'perceptions',
#  'risky',
#  'on-going',
#  'cup',
#  'links',
#  'ondo',
#  'assessed',
#  'stimuluscheck',
#  'safest',
#  'harm',
#  'vegas',
#  'one-third',
#  'csir',
#  'wireless',
#  'prod',
#  'connected',
#  'pendamic',
#  'chinamustexplain',
#  'layoffs',
#  'bcpoli',
#  'entertainment',
#  'quarantining',
#  'politicising',
#  'entities',
#  'cliff',
#  'lobbying',
#  'lanes',
#  'nnext',
#  'wales',
#  'escalates',
#  'herald',
#  'thanking',
#  'iit',
#  'vacation',
#  'rewrite',
#  'rathee',
#  'holding',
#  'involved',
#  'modiji',
#  'apologises',
#  'batteries',
#  'organic',
#  'ncan',
#  'locally',
#  'winding',
#  'wary',
#  'weserveandprotect',
#  'commodity',
#  'las',
#  'hormones',
#  'ndont',
#  'fuckers',
#  'escalate',
#  'gendered',
#  'logged',
#  'requirements',
#  'conway',
#  'sebi',
#  'sao',
#  'tab',
#  'smes',
#  'autumn',
#  'buses',
#  'sme',
#  'babetrayal',
#  'corner',
#  'stigma',
#  'nicotine',
#  'wouldnt',
#  'mistake',
#  'powered',
#  'quarantineandchill',
#  'purevpn',
#  'supplement',
#  'messenger',
#  'complicit',
#  'approving',
#  'stage',
#  'exploring',
#  'multi',
#  'chilling',
#  'poi',
#  'isle',
#  'westandwithitaly',
#  'ndonald',
#  'ncp',
#  'dropped',
#  'rolled',
#  'delusional',
#  'hussein',
#  'nominate',
#  'nworld',
#  'abiding',
#  'caves',
#  'nahin',
#  'swarms',
#  'bull',
#  'epc',
#  'webinars',
#  'truckers',
#  'cent',
#  "whitmer's",
#  'donatewithoutspending',
#  'nfl',
#  'fossil',
#  'failures',
#  'implies',
#  'selfisolation',
#  'strengthening',
#  'indoctrination',
#  'mannkibaat',
#  'experiences',
#  'tamil',
#  'combine',
#  'patent',
#  'compromised',
#  'hometown',
#  'defensive',
#  'scott',
#  'noticias',
#  'gathered',
#  'irrelevant',
#  'wipe',
#  'gavinnewsom',
#  'eager',
#  'pensioners',
#  'tol',
#  'disabled',
#  'cpho',
#  'nto',
#  'chatting',
#  'bang',
#  'substitute',
#  'imperative',
#  'alpha',
#  'cronies',
#  'champ',
#  'lewis',
#  'queues',
#  'forever',
#  'rating',
#  'fbpe',
#  'consequences',
#  'habit',
#  'combo',
#  'dollar',
#  'metre',
#  'walkers',
#  'spur',
#  'njohnson',
#  'economical',
#  'overwhelmed',
#  'investigation',
#  'nlisten',
#  'temporary',
#  'fixed',
#  'orchestra',
#  'femi',
#  'mercy',
#  'skye',
#  'nhey',
#  'unlocking',
#  'venmo',
#  'telecoms',
#  'witnessed',
#  'taekook',
#  'high-risk',
#  'timesofindia',
#  'subjected',
#  'niv',
#  'hoped',
#  'cps',
#  'judged',
#  'joncoopertweets',
#  'fame',
#  'indonesian',
#  'vegetarian',
#  'comprehensive',
#  'samples',
#  'diarrhoea',
#  'ken',
#  'creatives',
#  'delay',
#  'script',
#  'pandemi',
#  'mumbaipolice',
#  'bloody',
#  'bribe',
#  'culprits',
#  'overwhelmingly',
#  'miles',
#  'opsoms',
#  'injected',
#  'intensity',
#  'mlg',
#  'hmoindia',
#  'ramadhan',
#  'supplying',
#  'crimson',
#  'isc',
#  'zxr',
#  'pathways',
#  'hustle',
#  'surging',
#  'peel',
#  'subscription',
#  'ngrpresident',
#  'unexpected',
#  'reallyswara',
#  'usd',
#  'warp',
#  'ndespite',
#  'arnab',
#  'amended',
#  'lingering',
#  'oral',
#  'guangzhou',
#  'sai',
#  'resumes',
#  'sciences',
#  'sow',
#  'oooh',
#  'rulers',
#  'mothers',
#  'toe',
#  'defying',
#  'briefly',
#  'morocco',
#  'colour',
#  'busters',
#  'kid',
#  'ntopic',
#  'fav',
#  'bureaucrats',
#  "nwhat's",
#  'kellyannepolls',
#  'thailand',
#  'gulf',
#  'racing',
#  'georgeflyod',
#  'renamed',
#  'overtakes',
#  'seventeen',
#  'operates',
#  'pillow',
#  'industrial',
#  'mild',
#  'proportion',
#  'pissed',
#  'settlement',
#  'riots',
#  'vessels',
#  'evangelists',
#  'tryna',
#  'obligations',
#  'facemasks',
#  'cont',
#  'strategically',
#  'protester',
#  'participants',
#  'arteta',
#  ...]

# %% [markdown]
# ## Stemming tokens using  Porter stemmer

# %%
# stemming tokens using  Porter stemmer

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
unique_words = ['{1}'.format(u, stemmer.stem(u)) for u in unique_words]
unique_words = set(unique_words)
unique_words = list(unique_words)
unique_words.sort()
unique_words
# Out:
# ['aaa',
#  'aai',
#  'aajtak',
#  'aam',
#  'aamaadmiparti',
#  'aap',
#  'aarogya',
#  'aarogyasetu',
#  'aaron',
#  'aarp',
#  'aatmanirbharbharat',
#  'aayog',
#  'ab',
#  'aba',
#  'abandon',
#  'abayomi',
#  'abba',
#  'abbott',
#  'abcnew',
#  'abe',
#  'abeg',
#  'aberdeen',
#  'aberdeennew',
#  'abhi',
#  'abi',
#  'abia',
#  'abid',
#  'abil',
#  'aboard',
#  'abolish',
#  'aborigin',
#  'abort',
#  'abpnew',
#  'abroad',
#  'abruptli',
#  'abs-cbn',
#  'abscbnnew',
#  'absenc',
#  'absent',
#  'absente',
#  'absorb',
#  'abstract',
#  'absurd',
#  'abt',
#  'abu',
#  'abudhabi',
#  'abuja',
#  'abund',
#  'abus',
#  'abvpvoic',
#  'abysm',
#  'abyss',
#  'aca',
#  'academ',
#  'academi',
#  'academia',
#  'acb',
#  'acc',
#  'acceler',
#  'accept',
#  'access',
#  'accessori',
#  'accid',
#  'accident',
#  'accommod',
#  'accompani',
#  'accomplish',
#  'account',
#  'accumul',
#  'accur',
#  'accuraci',
#  'accus',
#  'acd',
#  'ace',
#  'aceng',
#  'acgrayl',
#  'ach',
#  'achiev',
#  'acid',
#  'acknowledg',
#  'aclu',
#  'acosta',
#  'acquir',
#  'acquisit',
#  'acquit',
#  'acronym',
#  'act',
#  'action',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'acut',
#  'ad',
#  'ada',
#  'adam',
#  'adamawa',
#  'adamboultonski',
#  'adamparkhomenko',
#  'adani',
#  'adapt',
#  'adb',
#  'add',
#  'addict',
#  'addit',
#  'addo',
#  'address',
#  'adeboy',
#  'adelaid',
#  'aden',
#  'adequ',
#  'adhanom',
#  'adher',
#  'adityanath',
#  'adjust',
#  'adm',
#  'admin',
#  'administ',
#  'administr',
#  "administration'",
#  'admir',
#  'admiss',
#  'admit',
#  'ado',
#  'adoni',
#  'adopt',
#  'ador',
#  'adult',
#  'adv',
#  'advanc',
#  'advantag',
#  'advent',
#  'adventur',
#  'advers',
#  'advert',
#  'advertis',
#  'advis',
#  'advisor',
#  'advisori',
#  'advobarryroux',
#  'advoc',
#  'advocaci',
#  'aei',
#  'aerial',
#  'aerosol',
#  'aerospac',
#  'aest',
#  'afc',
#  'afdb',
#  'aff',
#  'affair',
#  'affect',
#  'affili',
#  'afford',
#  'afg',
#  'afghan',
#  'afghanistan',
#  'afl',
#  'afloat',
#  'afneil',
#  'afp',
#  'afraid',
#  "africa'",
#  'africacdc',
#  'africaday',
#  'african',
#  'africanunion',
#  'aftermath',
#  'afternoon',
#  'afthunderbird',
#  'ag',
#  'agar',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'aggress',
#  'agil',
#  'agm',
#  'agp',
#  'agra',
#  'agre',
#  'agreement',
#  'agri',
#  'agricultur',
#  'ahh',
#  'ahhh',
#  'ahm',
#  'ahmedabad',
#  'aict',
#  'aid',
#  'aiim',
#  'ail',
#  'aim',
#  'ain',
#  'aint',
#  'air',
#  'airbnb',
#  'airborn',
#  'airbu',
#  'aircraft',
#  'airforc',
#  'airindia',
#  'airindiain',
#  'airlift',
#  'airlin',
#  'airnewsalert',
#  'airplan',
#  'airpollut',
#  'airport',
#  'airtel',
#  'airway',
#  'ait',
#  'aja',
#  'ajay',
#  'ajc',
#  'ajenew',
#  'ajenglish',
#  'ajitpawarspeak',
#  'ajk',
#  'aka',
#  'akg',
#  'akin',
#  'ako',
#  'akshay',
#  'akshaykumar',
#  'aku',
#  'akufo-addo',
#  'akwa',
#  'al',
#  'ala',
#  'alabama',
#  'alam',
#  'alan',
#  'alarabiya',
#  'alarm',
#  'alarmist',
#  'alaska',
#  'albeit',
#  'albert',
#  'alberta',
#  'alberto',
#  'albomp',
#  'album',
#  'alcohol',
#  'alcohol-bas',
#  'alert',
#  'alex',
#  'alexa',
#  'alexand',
#  'alexberenson',
#  'algorithm',
#  'alhamdulillah',
#  'ali',
#  'alibaba',
#  'alibabagroup',
#  'alic',
#  'alien',
#  'align',
#  'alik',
#  'alistairhaim',
#  'aliv',
#  'aljazeera',
#  'all-tim',
#  'allah',
#  'alleg',
#  'allegedli',
#  'allen',
#  'allergi',
#  'allevi',
#  'alli',
#  'allianc',
#  'allinthistogeth',
#  'allisonpearson',
#  'alloc',
#  'allow',
#  'almajiri',
#  'almighti',
#  'alok',
#  'aloksharma',
#  'alonetogeth',
#  'alongsid',
#  'alot',
#  'alpha',
#  'alright',
#  'alt',
#  'altar',
#  'alter',
#  'altern',
#  'altogeth',
#  'alumni',
#  'alyssa',
#  'alzheim',
#  'ama',
#  'amanda',
#  'amarind',
#  'amaz',
#  'amb',
#  'ambassador',
#  'ambit',
#  'ambiti',
#  'ambul',
#  'amc',
#  'ame',
#  'ameen',
#  'amen',
#  'amend',
#  'america',
#  "america'",
#  'americafirst',
#  "american'",
#  'americastrong',
#  'amermedicalassn',
#  'amg',
#  'ami',
#  'amici',
#  'amidst',
#  'amit',
#  'amitabhk',
#  'amitmalviya',
#  'amitshah',
#  'amnesia',
#  'amnesti',
#  'amount',
#  'amphan',
#  'ampl',
#  'amplifi',
#  'amrn',
#  'amsterdam',
#  'amtrak',
#  'amu',
#  'amus',
#  'amwrit',
#  'an',
#  'ana',
#  'analys',
#  'analyst',
#  'analyt',
#  'analyz',
#  'anambra',
#  'anand',
#  'anandmahindra',
#  'anantnag',
#  'anarchi',
#  'anc',
#  'anchor',
#  'ancient',
#  'andaman',
#  'ander',
#  'anderson',
#  'andersoncoop',
#  'andhra',
#  'andhrapradesh',
#  'andhrapradeshcm',
#  'andi',
#  'andr',
#  'andrea',
#  'andrew',
#  'andrewcuomo',
#  'andrewmarr',
#  'andrewyang',
#  'android',
#  'anesthesia',
#  'ang',
#  'angel',
#  'angela',
#  'angelarayn',
#  'anger',
#  'angl',
#  'angri',
#  'angu',
#  'ani',
#  'anil',
#  'anilvijminist',
#  'anim',
#  'anjanaomkashyap',
#  'ann',
#  'anna',
#  'annastaciamp',
#  'anniversari',
#  'announc',
#  'annoy',
#  'annual',
#  'ano',
#  'anonym',
#  'answer',
#  'ant',
#  'antenat',
#  'antgrasso',
#  'anthem',
#  'anthoni',
#  'anti',
#  'anti-asian',
#  'anti-coronaviru',
#  'anti-covid',
#  'anti-inflammatori',
#  'anti-lockdown',
#  'anti-malari',
#  'anti-malaria',
#  'anti-rac',
#  'anti-trump',
#  'anti-vaxx',
#  'anti-vir',
#  'antibacteri',
#  'antibiot',
#  'antibodi',
#  'antic',
#  'anticip',
#  'antidot',
#  'antifa',
#  'antimalari',
#  'antisemit',
#  'antivaxx',
#  'antivir',
#  'antonio',
#  'antonioguterr',
#  'anu',
#  'anurag',
#  'anxieti',
#  'anxiou',
#  'anxious',
#  'anymor',
#  'anytim',
#  'anz',
#  'anzac',
#  'aoc',
#  'aol',
#  'apac',
#  'apart',
#  'apc',
#  'ape',
#  'apex',
#  'apfightscorona',
#  'api',
#  'apn',
#  'apocalyps',
#  'apocalypt',
#  'apollo',
#  'apolog',
#  'apologis',
#  'app',
#  'appal',
#  'appar',
#  'apparel',
#  'appeal',
#  'appear',
#  'appeas',
#  'appetit',
#  'appl',
#  'applaud',
#  'applaus',
#  'appli',
#  'applic',
#  'appnew',
#  'appoint',
#  'appreci',
#  'approach',
#  'appropri',
#  'approv',
#  'approx',
#  'approxim',
#  'appt',
#  'apr',
#  'aproko',
#  'apt',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabnew',
#  'aranganathan',
#  'arbitrari',
#  'archbishop',
#  'architect',
#  'architectur',
#  'archiv',
#  'ard',
#  'ardern',
#  'arena',
#  'arent',
#  'argentina',
#  'argu',
#  'arguabl',
#  'argument',
#  'ari',
#  'aris',
#  'arisen',
#  'arizona',
#  'arkansa',
#  'arm',
#  'armageddon',
#  'armchair',
#  'armenia',
#  'armenian',
#  'armstrong',
#  'arnab',
#  'arnold',
#  'arogya',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'ars',
#  'arsen',
#  'art',
#  'artcal',
#  'arteta',
#  'arthriti',
#  'arthur',
#  'articl',
#  'articul',
#  'artifici',
#  'artificialintellig',
#  'artinthetimeofcovid',
#  'artist',
#  'artistcal',
#  'artistontwitt',
#  'artistscal',
#  'artpromot',
#  'artwork',
#  'arunach',
#  'arvind',
#  'arvindkejriw',
#  'arynew',
#  'asa',
#  'asad',
#  'asadowaisi',
#  'asap',
#  'ascertain',
#  'asda',
#  'asean',
#  'ash',
#  'asham',
#  'ashley',
#  'ashokgehlot',
#  'ashoswai',
#  'ashwinikchoubey',
#  "asia'",
#  'asian',
#  'asinin',
#  'ask',
#  'askdrh',
#  'asl',
#  'aslavitt',
#  'asleep',
#  'aso',
#  'aspect',
#  'aspir',
#  'ass',
#  'assam',
#  'assamcovidcount',
#  'assang',
#  'assault',
#  'assembl',
#  'assert',
#  'assess',
#  'asset',
#  'asshol',
#  'assign',
#  'assist',
#  'associ',
#  'assum',
#  'assumpt',
#  'assur',
#  'asthma',
#  'aston',
#  'astonish',
#  'astound',
#  'astrazeneca',
#  'astronaut',
#  'astronomi',
#  'asu',
#  'asx',
#  'asylum',
#  'at',
#  'at-hom',
#  'at-risk',
#  'ata',
#  'ate',
#  'athen',
#  'athlet',
#  'athom',
#  'ati',
#  'atiku',
#  'atl',
#  'atla',
#  'atlant',
#  'atlanta',
#  'atleast',
#  'atm',
#  'atmanirbhar',
#  'atmospher',
#  'ato',
#  'atrupar',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attende',
#  'attitud',
#  'attn',
#  'attorney',
#  'attract',
#  'attribut',
#  'au',
#  'auckland',
#  'auction',
#  'audac',
#  'audienc',
#  'audio',
#  'audit',
#  'aug',
#  'august',
#  'aun',
#  'aunt',
#  'aup',
#  'aur',
#  'ausgov',
#  'aussi',
#  'auster',
#  'austin',
#  "australia'",
#  'australian',
#  'austria',
#  'austrian',
#  'authackeray',
#  'authent',
#  'author',
#  'authoris',
#  'authorit',
#  'authoritarian',
#  'autism',
#  'autist',
#  'auto',
#  'autocrat',
#  'autoimmun',
#  'autom',
#  'automat',
#  'automobil',
#  'automot',
#  'autonomi',
#  'autopsi',
#  'autumn',
#  'auv',
#  'avail',
#  'avalanch',
#  'avct',
#  'ave',
#  'avenu',
#  'averag',
#  'avert',
#  'avg',
#  'avgeek',
#  'avi',
#  'aviat',
#  'avid',
#  'avigan',
#  'avm',
#  'avoid',
#  'aw',
#  'await',
#  'awak',
#  'awaken',
#  'awar',
#  'award',
#  'awe',
#  'awesom',
#  'awhil',
#  'awkward',
#  'awp',
#  'awu',
#  'axa',
#  'axe',
#  'axi',
#  'axio',
#  'axt',
#  'aye',
#  'aynrand',
#  'ayo',
#  'aytu',
#  'ayurved',
#  'ayurveda',
#  'ayush',
#  'azar',
#  'azithromycin',
#  'azn',
#  'azt',
#  'azur',
#  'ba',
#  'baad',
#  'baat',
#  'baba',
#  'babetray',
#  'babi',
#  'babu',
#  'back',
#  'back-to',
#  'backbon',
#  'backdrop',
#  'backfir',
#  'background',
#  'backlash',
#  'backlog',
#  'backtoschool',
#  'backtowork',
#  'backup',
#  'backward',
#  'backyard',
#  'bacteri',
#  'bacteria',
#  'badg',
#  'badli',
#  'bae',
#  'baffl',
#  'bag',
#  'baguio',
#  'bahrain',
#  'bail',
#  'bailey',
#  'bailout',
#  'bait',
#  'bajaj',
#  'bajucovid',
#  'bake',
#  'baker',
#  'bakeri',
#  'bakit',
#  'balanc',
#  'balasor',
#  'balconi',
#  'bali',
#  'ball',
#  'balloon',
#  'ballot',
#  'balm',
#  'balochistan',
#  'baltic',
#  'baltimor',
#  'bam',
#  'bame',
#  'ban',
#  'banana',
#  'band',
#  'bandwagon',
#  'banerje',
#  'bang',
#  'bangalor',
#  'bangkok',
#  'bangkokpost',
#  'bangladesh',
#  'bangladeshi',
#  'bank',
#  'banker',
#  'bankholiday',
#  'bankrupt',
#  'bankruptci',
#  'banksi',
#  'banner',
#  'baptist',
#  'bar',
#  'barack',
#  'barackobama',
#  'baramulla',
#  'barangay',
#  'barbara',
#  'barber',
#  'barbershop',
#  'barcelona',
#  'barclay',
#  'bare',
#  'bargain',
#  'barley',
#  'barn',
#  'barr',
#  'barrel',
#  'barri',
#  'barrier',
#  'bart',
#  'base',
#  'basebal',
#  'basement',
#  'bash',
#  'bashirahmaad',
#  'basi',
#  'basic',
#  'basicincom',
#  'basket',
#  'basketbal',
#  'baskin',
#  'bastard',
#  'bat',
#  'batch',
#  'bath',
#  'bathroom',
#  'batman',
#  'batshit',
#  'batter',
#  'batteri',
#  'battl',
#  'battlefield',
#  'battleground',
#  'bauchi',
#  'bay',
#  'bayanihan',
#  'bayelsa',
#  'bazaar',
#  'bazar',
#  "bbc'",
#  'bbcafrica',
#  'bbcbreak',
#  'bbcbreakfast',
#  'bbcbusi',
#  'bbcindia',
#  'bbclaurak',
#  'bbcnewsnight',
#  'bbcnickrobinson',
#  'bbcpolit',
#  'bbcquestiontim',
#  'bbcr',
#  'bbcradio',
#  'bbcscotlandnew',
#  'bbcworld',
#  'bbhuttozardari',
#  'bbnaija',
#  'bbq',
#  'bc',
#  'bcci',
#  'bcg',
#  'bco',
#  'bcoz',
#  'bcp',
#  'bcpoli',
#  'bcz',
#  'bda',
#  'bday',
#  'bdo',
#  'bdutt',
#  'be',
#  'beach',
#  'beacon',
#  'bean',
#  'bear',
#  'beast',
#  'beat',
#  'beatcovid',
#  'beaten',
#  'beattheviru',
#  'beauti',
#  'beauvau',
#  'bed',
#  'bedroom',
#  'bee',
#  'beef',
#  'beer',
#  'beg',
#  'began',
#  'beggar',
#  'begin',
#  'begun',
#  'behalf',
#  'behav',
#  'behavior',
#  'behavioralsci',
#  'behaviour',
#  'behold',
#  'beij',
#  "beijing'",
#  'beingsalmankhan',
#  'bekind',
#  'belaru',
#  'belfast',
#  'belgian',
#  'belgium',
#  'belief',
#  'believ',
#  'believeyourposs',
#  'beliv',
#  'bell',
#  'belli',
#  'bello',
#  'belong',
#  'belov',
#  'belt',
#  'ben',
#  'bench',
#  'benchmark',
#  'bend',
#  'benedict',
#  'benefici',
#  'beneficiari',
#  'benefit',
#  'bengal',
#  'bengaluru',
#  'benghazi',
#  'bennett',
#  'bennyjohnson',
#  'benshapiro',
#  'bent',
#  'benu',
#  'bereav',
#  'berespons',
#  'berlin',
#  'bernard',
#  'berni',
#  'berniesand',
#  'berri',
#  'bersatu',
#  'besaf',
#  'bet',
#  'beta',
#  'betfair',
#  'bethrigbi',
#  'betray',
#  'better',
#  'betti',
#  'bewar',
#  'bezo',
#  'bfh',
#  'bfp',
#  'bgc',
#  'bhai',
#  'bhakt',
#  'bharat',
#  'bhi',
#  'bhopal',
#  'bhubaneswar',
#  'bhupeshbaghel',
#  'bia',
#  'biafra',
#  'bias',
#  'bibl',
#  'biblic',
#  'bicycl',
#  'bid',
#  "biden'",
#  'bigdata',
#  'bigger',
#  'bigpharma',
#  'bihar',
#  'bike',
#  'biko',
#  'bil',
#  'bilater',
#  'bile',
#  'bill',
#  'billboard',
#  'billdeblasio',
#  'billgat',
#  'billgatesisevil',
#  'billgatesviru',
#  'billi',
#  'billion',
#  'billionair',
#  'billkristol',
#  'billoreilli',
#  'bin',
#  'bing',
#  'bingo',
#  'bio',
#  'biodivers',
#  'biolog',
#  'biomed',
#  'biosecur',
#  'biotech',
#  'biotechnolog',
#  'bioterror',
#  'bioweapon',
#  'bipartisan',
#  'bird',
#  'birmingham',
#  'birth',
#  'birthday',
#  'birx',
#  'biscuit',
#  'bishop',
#  'bit',
#  'bitch',
#  'bitchut',
#  'bitcoin',
#  'bitcoinincoin',
#  'bite',
#  'bitter',
#  'biz',
#  'bizarr',
#  'bjw',
#  'bkr',
#  'black',
#  'blacklivesmatt',
#  'blackmail',
#  'blackout',
#  'blackpink',
#  'blacktwitt',
#  'blah',
#  'blair',
#  'blame',
#  'blanket',
#  'blasio',
#  'blast',
#  'blatant',
#  'blatantli',
#  'bleach',
#  ...]

# %%
len(unique_words)
# Out:
# 11539

# %% [markdown]
# ## Adding the pmi_bigrams to the unique words list from above

# %%
vocab_list = unique_words+pmi_bigrams
sorted_vocab = sorted(vocab_list)
sorted_vocab
# Out:
# ['aaa',
#  'aai',
#  'aajtak',
#  'aam',
#  'aamaadmiparti',
#  'aap',
#  'aarogya',
#  'aarogya_setu',
#  'aarogyasetu',
#  'aaron',
#  'aarp',
#  'aatmanirbharbharat',
#  'aayog',
#  'ab',
#  'aba',
#  'abandon',
#  'abayomi',
#  'abba',
#  'abba_kyari',
#  'abbott',
#  'abcnew',
#  'abe',
#  'abeg',
#  'aberdeen',
#  'aberdeennew',
#  'abhi',
#  'abi',
#  'abia',
#  'abid',
#  'abil',
#  'aboard',
#  'abolish',
#  'aborigin',
#  'abort',
#  'abpnew',
#  'abroad',
#  'abruptli',
#  'abs-cbn',
#  'abscbnnew',
#  'absenc',
#  'absent',
#  'absente',
#  'absorb',
#  'abstract',
#  'absurd',
#  'abt',
#  'abu',
#  'abudhabi',
#  'abuja',
#  'abund',
#  'abus',
#  'abvpvoic',
#  'abysm',
#  'abyss',
#  'aca',
#  'academ',
#  'academi',
#  'academia',
#  'acb',
#  'acc',
#  'acceler',
#  'accept',
#  'access',
#  'accessori',
#  'accid',
#  'accident',
#  'accommod',
#  'accompani',
#  'accomplish',
#  'account',
#  'accumul',
#  'accur',
#  'accuraci',
#  'accus',
#  'acd',
#  'ace',
#  'aceng',
#  'acgrayl',
#  'ach',
#  'achiev',
#  'achyuta_samanta',
#  'acid',
#  'acknowledg',
#  'aclu',
#  'acosta',
#  'acquir',
#  'acquisit',
#  'acquit',
#  'acronym',
#  'act',
#  'action',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'acut',
#  'ad',
#  'ada',
#  'adam',
#  'adamawa',
#  'adamboultonski',
#  'adamparkhomenko',
#  'adani',
#  'adapt',
#  'adb',
#  'add',
#  'addict',
#  'adding_value',
#  'addit',
#  'addo',
#  'address',
#  'adeboy',
#  'adelaid',
#  'aden',
#  'adequ',
#  'adhanom',
#  'adher',
#  'adityanath',
#  'adjust',
#  'adm',
#  'admin',
#  'administ',
#  'administr',
#  "administration'",
#  'admir',
#  'admiss',
#  'admit',
#  'ado',
#  'adoni',
#  'adopt',
#  'ador',
#  'ads_suggests',
#  'adult',
#  'adv',
#  'advanc',
#  'advantag',
#  'advent',
#  'adventur',
#  'advers',
#  'advert',
#  'advertis',
#  'advis',
#  'advisor',
#  'advisori',
#  'advobarryroux',
#  'advoc',
#  'advocaci',
#  'aei',
#  'aerial',
#  'aerosol',
#  'aerospac',
#  'aest',
#  'afc',
#  'afdb',
#  'aff',
#  'affair',
#  'affect',
#  'affili',
#  'afford',
#  'afg',
#  'afghan',
#  'afghanistan',
#  'afl',
#  'afloat',
#  'afneil',
#  'afp',
#  'afraid',
#  "africa'",
#  'africacdc',
#  'africaday',
#  'african',
#  'africanunion',
#  'aftermath',
#  'afternoon',
#  'afthunderbird',
#  'ag',
#  'agar',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'aggress',
#  'agil',
#  'agm',
#  'agp',
#  'agra',
#  'agre',
#  'agreement',
#  'agri',
#  'agricultur',
#  'ahh',
#  'ahhh',
#  'ahm',
#  'ahmedabad',
#  'aict',
#  'aid',
#  'aiim',
#  'ail',
#  'aim',
#  'ain',
#  'aint',
#  'air',
#  'air_pollution',
#  'airbnb',
#  'airborn',
#  'airbu',
#  'aircraft',
#  'airforc',
#  'airindia',
#  'airindiain',
#  'airlift',
#  'airlin',
#  'airnewsalert',
#  'airplan',
#  'airpollut',
#  'airport',
#  'airtel',
#  'airway',
#  'ait',
#  'aja',
#  'ajay',
#  'ajc',
#  'ajenew',
#  'ajenglish',
#  'ajitpawarspeak',
#  'ajk',
#  'aka',
#  'akg',
#  'akin',
#  'ako',
#  'akshay',
#  'akshaykumar',
#  'aku',
#  'akufo-addo',
#  'akwa',
#  'al',
#  'ala',
#  'alabama',
#  'alam',
#  'alan',
#  'alarabiya',
#  'alarm',
#  'alarmist',
#  'alaska',
#  'albeit',
#  'albert',
#  'alberta',
#  'alberto',
#  'albomp',
#  'album',
#  'alcohol',
#  'alcohol-bas',
#  'alert',
#  'alex',
#  'alexa',
#  'alexand',
#  'alexberenson',
#  'algorithm',
#  'alhamdulillah',
#  'ali',
#  'alibaba',
#  'alibabagroup',
#  'alic',
#  'alien',
#  'align',
#  'alik',
#  'alistairhaim',
#  'aliv',
#  'aljazeera',
#  'all-tim',
#  'allah',
#  'alleg',
#  'allegedli',
#  'allen',
#  'allergi',
#  'allevi',
#  'alli',
#  'allianc',
#  'allinthistogeth',
#  'allisonpearson',
#  'alloc',
#  'allow',
#  'almajiri',
#  'almighti',
#  'alok',
#  'aloksharma',
#  'alonetogeth',
#  'alongsid',
#  'alot',
#  'alpha',
#  'alright',
#  'alt',
#  'altar',
#  'alter',
#  'altern',
#  'altogeth',
#  'alumni',
#  'alyssa',
#  'alzheim',
#  'ama',
#  'amanda',
#  'amarind',
#  'amaz',
#  'amb',
#  'ambassador',
#  'ambit',
#  'ambiti',
#  'ambul',
#  'amc',
#  'ame',
#  'ameen',
#  'amen',
#  'amend',
#  'america',
#  "america'",
#  'americafirst',
#  "american'",
#  'americastrong',
#  'amermedicalassn',
#  'amg',
#  'ami',
#  'amici',
#  'amici_siamo',
#  'amidst',
#  'amit',
#  'amitabhk',
#  'amitmalviya',
#  'amitshah',
#  'amnesia',
#  'amnesti',
#  'amount',
#  'amphan',
#  'ampl',
#  'amplifi',
#  'amrn',
#  'amsterdam',
#  'amtrak',
#  'amu',
#  'amus',
#  'amwrit',
#  'an',
#  'ana',
#  'analys',
#  'analyst',
#  'analyt',
#  'analyz',
#  'anambra',
#  'anand',
#  'anandmahindra',
#  'anantnag',
#  'anarchi',
#  'anc',
#  'anchor',
#  'ancient',
#  'andaman',
#  'ander',
#  'anderson',
#  'andersoncoop',
#  'andhra',
#  'andhra_pradesh',
#  'andhrapradesh',
#  'andhrapradeshcm',
#  'andi',
#  'andr',
#  'andrea',
#  'andrew',
#  'andrew_cuomo',
#  'andrewcuomo',
#  'andrewmarr',
#  'andrewyang',
#  'android',
#  'anesthesia',
#  'ang',
#  'angel',
#  'angela',
#  'angelarayn',
#  'anger',
#  'angl',
#  'angri',
#  'angu',
#  'ani',
#  'anil',
#  'anilvijminist',
#  'anim',
#  'anjanaomkashyap',
#  'ann',
#  'anna',
#  'annastaciamp',
#  'anniversari',
#  'announc',
#  'annoy',
#  'annual',
#  'ano',
#  'anonym',
#  'answer',
#  'ant',
#  'antenat',
#  'antgrasso',
#  'anthem',
#  'anthoni',
#  'anthony_fauci',
#  'anti',
#  'anti-asian',
#  'anti-coronaviru',
#  'anti-covid',
#  'anti-inflammatori',
#  'anti-lockdown',
#  'anti-malari',
#  'anti-malaria',
#  'anti-rac',
#  'anti-trump',
#  'anti-vaxx',
#  'anti-vir',
#  'antibacteri',
#  'antibiot',
#  'antibodi',
#  'antic',
#  'anticip',
#  'antidot',
#  'antifa',
#  'antimalari',
#  'antisemit',
#  'antivaxx',
#  'antivir',
#  'antonio',
#  'antonioguterr',
#  'anu',
#  'anurag',
#  'anxieti',
#  'anxiou',
#  'anxious',
#  'anymor',
#  'anytim',
#  'anz',
#  'anzac',
#  'aoc',
#  'aol',
#  'apac',
#  'apart',
#  'apc',
#  'ape',
#  'apex',
#  'apfightscorona',
#  'api',
#  'apn',
#  'apocalyps',
#  'apocalypt',
#  'apollo',
#  'apolog',
#  'apologis',
#  'app',
#  'appal',
#  'appar',
#  'apparel',
#  'appeal',
#  'appear',
#  'appeas',
#  'appetit',
#  'appl',
#  'applaud',
#  'applaus',
#  'appli',
#  'applic',
#  'appnew',
#  'appoint',
#  'appreci',
#  'approach',
#  'appropri',
#  'approv',
#  'approx',
#  'approxim',
#  'appt',
#  'apr',
#  'aproko',
#  'apt',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabnew',
#  'aranganathan',
#  'arbitrari',
#  'archbishop',
#  'architect',
#  'architectur',
#  'archiv',
#  'ard',
#  'ardern',
#  'arena',
#  'arent',
#  'argentina',
#  'argu',
#  'arguabl',
#  'argument',
#  'ari',
#  'aris',
#  'arisen',
#  'arizona',
#  'arkansa',
#  'arm',
#  'armageddon',
#  'armchair',
#  'armed_forces',
#  'armenia',
#  'armenian',
#  'armstrong',
#  'arnab',
#  'arnold',
#  'arogya',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'ars',
#  'arsen',
#  'art',
#  'artcal',
#  'arteta',
#  'arthriti',
#  'arthur',
#  'articl',
#  'articul',
#  'artifici',
#  'artificial_intelligence',
#  'artificialintellig',
#  'artinthetimeofcovid',
#  'artist',
#  'artistcal',
#  'artistontwitt',
#  'artistscal',
#  'artpromot',
#  'artwork',
#  'arunach',
#  'arvind',
#  'arvind_kejriwal',
#  'arvindkejriw',
#  'arynew',
#  'asa',
#  'asad',
#  'asadowaisi',
#  'asap',
#  'ascertain',
#  'asda',
#  'asean',
#  'ash',
#  'asham',
#  'ashley',
#  'ashokgehlot',
#  'ashoswai',
#  'ashwinikchoubey',
#  "asia'",
#  'asian',
#  'asinin',
#  'ask',
#  'askdrh',
#  'asl',
#  'aslavitt',
#  'asleep',
#  'aso',
#  'aspect',
#  'aspir',
#  'ass',
#  'assam',
#  'assamcovidcount',
#  'assang',
#  'assault',
#  'assembl',
#  'assert',
#  'assess',
#  'asset',
#  'asshol',
#  'assign',
#  'assist',
#  'associ',
#  'assum',
#  'assumpt',
#  'assur',
#  'asthma',
#  'aston',
#  'astonish',
#  'astound',
#  'astrazeneca',
#  'astronaut',
#  'astronomi',
#  'asu',
#  'asx',
#  'asylum',
#  'at',
#  'at-hom',
#  'at-risk',
#  'ata',
#  'ate',
#  'athen',
#  'athlet',
#  'athom',
#  'ati',
#  'atiku',
#  'atl',
#  'atla',
#  'atlant',
#  'atlanta',
#  'atleast',
#  'atm',
#  'atmanirbhar',
#  'atmospher',
#  'ato',
#  'atrupar',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attende',
#  'attitud',
#  'attn',
#  'attorney',
#  'attract',
#  'attribut',
#  'au',
#  'auckland',
#  'auction',
#  'audac',
#  'audienc',
#  'audio',
#  'audit',
#  'aug',
#  'august',
#  'aun',
#  'aunt',
#  'aup',
#  'aur',
#  'ausgov',
#  'aussi',
#  'auster',
#  'austin',
#  "australia'",
#  'australian',
#  'austria',
#  'austrian',
#  'authackeray',
#  'authent',
#  'author',
#  'authoris',
#  'authorit',
#  'authoritarian',
#  'autism',
#  'autist',
#  'auto',
#  'autocrat',
#  'autoimmun',
#  'autom',
#  'automat',
#  'automobil',
#  'automot',
#  'autonomi',
#  'autopsi',
#  'autumn',
#  'auv',
#  'avail',
#  'avalanch',
#  'avct',
#  'ave',
#  'avenu',
#  'averag',
#  'avert',
#  'avg',
#  'avgeek',
#  'avi',
#  'aviat',
#  'avid',
#  'avigan',
#  'avm',
#  'avoid',
#  'aw',
#  'await',
#  'awak',
#  'awaken',
#  'awar',
#  'award',
#  'awe',
#  'awesom',
#  'awhil',
#  'awkward',
#  'awp',
#  'awu',
#  'axa',
#  'axe',
#  'axi',
#  'axio',
#  'axt',
#  'aye',
#  'aynrand',
#  'ayo',
#  'aytu',
#  'ayurved',
#  'ayurveda',
#  'ayush',
#  'azar',
#  'azithromycin',
#  'azn',
#  'azt',
#  'azur',
#  'ba',
#  'baad',
#  'baat',
#  'baba',
#  'babetray',
#  'babi',
#  'babu',
#  'back',
#  'back-to',
#  'backbon',
#  'backdrop',
#  'backfir',
#  'background',
#  'backlash',
#  'backlog',
#  'backtoschool',
#  'backtowork',
#  'backup',
#  'backward',
#  'backyard',
#  'bacteri',
#  'bacteria',
#  'badg',
#  'badli',
#  'bae',
#  'baffl',
#  'bag',
#  'baguio',
#  'bahrain',
#  'bail',
#  'bailey',
#  'bailout',
#  'bait',
#  'bajaj',
#  'bajucovid',
#  'bake',
#  'baker',
#  'bakeri',
#  'bakit',
#  'balanc',
#  'balasor',
#  'balconi',
#  'bali',
#  'ball',
#  'balloon',
#  'ballot',
#  'balm',
#  'balochistan',
#  'baltic',
#  'baltimor',
#  'bam',
#  'bame',
#  'ban',
#  'banana',
#  'band',
#  'bandwagon',
#  'banerje',
#  'bang',
#  'bangalor',
#  'bangkok',
#  'bangkokpost',
#  'bangladesh',
#  'bangladeshi',
#  'bank',
#  'banker',
#  'bankholiday',
#  'bankrupt',
#  'bankruptci',
#  'banksi',
#  'banner',
#  'baptist',
#  'bar',
#  'barack',
#  'barackobama',
#  'baramulla',
#  'barangay',
#  'barbara',
#  'barber',
#  'barbershop',
#  'barcelona',
#  'barclay',
#  'bare',
#  'bargain',
#  'barley',
#  'barn',
#  'barr',
#  'barrel',
#  'barri',
#  'barrier',
#  'bart',
#  'base',
#  'basebal',
#  'basement',
#  'bash',
#  'bashirahmaad',
#  'basi',
#  'basic',
#  'basicincom',
#  'basket',
#  'basketbal',
#  'baskin',
#  'bastard',
#  'bat',
#  'batch',
#  'bath',
#  'bathroom',
#  'batman',
#  'batshit',
#  'batter',
#  'batteri',
#  'battl',
#  'battlefield',
#  'battleground',
#  'bauchi',
#  'bay',
#  'bay_area',
#  'bayanihan',
#  'bayelsa',
#  'bazaar',
#  'bazar',
#  "bbc'",
#  'bbcafrica',
#  'bbcbreak',
#  'bbcbreakfast',
#  'bbcbusi',
#  'bbcindia',
#  'bbclaurak',
#  'bbcnewsnight',
#  'bbcnickrobinson',
#  'bbcpolit',
#  'bbcquestiontim',
#  'bbcr',
#  'bbcr_today',
#  'bbcradio',
#  'bbcscotlandnew',
#  'bbcworld',
#  'bbhuttozardari',
#  'bbnaija',
#  'bbq',
#  'bc',
#  'bcci',
#  'bcg',
#  'bco',
#  'bcoz',
#  'bcp',
#  'bcpoli',
#  'bcz',
#  'bda',
#  'bday',
#  'bdo',
#  'bdutt',
#  'be',
#  'beach',
#  'beacon',
#  'bean',
#  'bear',
#  'beast',
#  'beat',
#  'beatcovid',
#  'beaten',
#  'beaten_play',
#  'beattheviru',
#  'beauti',
#  'beauvau',
#  'bed',
#  'bedroom',
#  'bee',
#  'beef',
#  'beer',
#  'beg',
#  'began',
#  'beggar',
#  'begin',
#  'begun',
#  'behalf',
#  'behav',
#  'behavior',
#  'behavioralsci',
#  'behaviour',
#  'behold',
#  'beij',
#  "beijing'",
#  'beingsalmankhan',
#  'bekind',
#  'belaru',
#  'belfast',
#  'belgian',
#  'belgium',
#  'belief',
#  'believ',
#  'believeyourposs',
#  'believeyourpossibilities_stayhomesafelives',
#  'beliv',
#  'bell',
#  'belli',
#  'bello',
#  'belong',
#  'belov',
#  'belt',
#  'ben',
#  'bench',
#  'benchmark',
#  'bend',
#  'benedict',
#  'benefici',
#  'beneficiari',
#  'benefit',
#  'bengal',
#  'bengaluru',
#  'benghazi',
#  'bennett',
#  'bennyjohnson',
#  'benshapiro',
#  'bent',
#  'benu',
#  'bereav',
#  'berespons',
#  'berlin',
#  'bernard',
#  'berni',
#  'berniesand',
#  'berri',
#  'bersatu',
#  'besaf',
#  'bet',
#  'beta',
#  'betfair',
#  'bethrigbi',
#  'betray',
#  'better',
#  'betti',
#  'bewar',
#  'bezo',
#  'bfh',
#  'bfp',
#  'bgc',
#  'bhai',
#  'bhakt',
#  'bharat',
#  'bhi',
#  'bhopal',
#  'bhubaneswar',
#  'bhupeshbaghel',
#  'bia',
#  'biafra',
#  'bias',
#  'bibl',
#  'biblic',
#  'bicycl',
#  'bid',
#  "biden'",
#  'big_pharma',
#  'bigdata',
#  'bigger',
#  'bigpharma',
#  'bihar',
#  'bike',
#  'biko',
#  'bil',
#  'bilater',
#  'bile',
#  'bill',
#  'bill_gates',
#  'billboard',
#  'billdeblasio',
#  'billgat',
#  'billgatesisevil',
#  'billgatesviru',
#  'billi',
#  'billion',
#  'billionair',
#  'billkristol',
#  'billoreilli',
#  'bin',
#  'bing',
#  'bingo',
#  'bio',
#  'biodivers',
#  'biolog',
#  'biomed',
#  'biosecur',
#  'biotech',
#  'biotechnolog',
#  'bioterror',
#  'bioweapon',
#  'bipartisan',
#  'bird',
#  'birmingham',
#  'birth',
#  'birthday',
#  'birx',
#  'biscuit',
#  'bishop',
#  'bit',
#  'bitch',
#  'bitchut',
#  'bitcoin',
#  'bitcoinincoin',
#  'bite',
#  'bitter',
#  ...]

# %%
len(sorted_vocab)
# Out:
# 11739

# %% [markdown]
# ## Turning sorted vocab list into a dictionary with index as value

# %%
# key value dictionary of sorted_vocab list

vocab_dict = {k: v for v, k in enumerate(sorted_vocab)}

# %%
print(vocab_dict)
# Out:
# {'aaa': 0, 'aai': 1, 'aajtak': 2, 'aam': 3, 'aamaadmiparti': 4, 'aap': 5, 'aarogya': 6, 'aarogya_setu': 7, 'aarogyasetu': 8, 'aaron': 9, 'aarp': 10, 'aatmanirbharbharat': 11, 'aayog': 12, 'ab': 13, 'aba': 14, 'abandon': 15, 'abayomi': 16, 'abba': 17, 'abba_kyari': 18, 'abbott': 19, 'abcnew': 20, 'abe': 21, 'abeg': 22, 'aberdeen': 23, 'aberdeennew': 24, 'abhi': 25, 'abi': 26, 'abia': 27, 'abid': 28, 'abil': 29, 'aboard': 30, 'abolish': 31, 'aborigin': 32, 'abort': 33, 'abpnew': 34, 'abroad': 35, 'abruptli': 36, 'abs-cbn': 37, 'abscbnnew': 38, 'absenc': 39, 'absent': 40, 'absente': 41, 'absorb': 42, 'abstract': 43, 'absurd': 44, 'abt': 45, 'abu': 46, 'abudhabi': 47, 'abuja': 48, 'abund': 49, 'abus': 50, 'abvpvoic': 51, 'abysm': 52, 'abyss': 53, 'aca': 54, 'academ': 55, 'academi': 56, 'academia': 57, 'acb': 58, 'acc': 59, 'acceler': 60, 'accept': 61, 'access': 62, 'accessori': 63, 'accid': 64, 'accident': 65, 'accommod': 66, 'accompani': 67, 'accomplish': 68, 'account': 69, 'accumul': 70, 'accur': 71, 'accuraci': 72, 'accus': 73, 'acd': 74, 'ace': 75, 'aceng': 76, 'acgrayl': 77, 'ach': 78, 'achiev': 79, 'achyuta_samanta': 80, 'acid': 81, 'acknowledg': 82, 'aclu': 83, 'acosta': 84, 'acquir': 85, 'acquisit': 86, 'acquit': 87, 'acronym': 88, 'act': 89, 'action': 90, 'activ': 91, 'activist': 92, 'actor': 93, 'actress': 94, 'acut': 95, 'ad': 96, 'ada': 97, 'adam': 98, 'adamawa': 99, 'adamboultonski': 100, 'adamparkhomenko': 101, 'adani': 102, 'adapt': 103, 'adb': 104, 'add': 105, 'addict': 106, 'adding_value': 107, 'addit': 108, 'addo': 109, 'address': 110, 'adeboy': 111, 'adelaid': 112, 'aden': 113, 'adequ': 114, 'adhanom': 115, 'adher': 116, 'adityanath': 117, 'adjust': 118, 'adm': 119, 'admin': 120, 'administ': 121, 'administr': 122, "administration'": 123, 'admir': 124, 'admiss': 125, 'admit': 126, 'ado': 127, 'adoni': 128, 'adopt': 129, 'ador': 130, 'ads_suggests': 131, 'adult': 132, 'adv': 133, 'advanc': 134, 'advantag': 135, 'advent': 136, 'adventur': 137, 'advers': 138, 'advert': 139, 'advertis': 140, 'advis': 141, 'advisor': 142, 'advisori': 143, 'advobarryroux': 144, 'advoc': 145, 'advocaci': 146, 'aei': 147, 'aerial': 148, 'aerosol': 149, 'aerospac': 150, 'aest': 151, 'afc': 152, 'afdb': 153, 'aff': 154, 'affair': 155, 'affect': 156, 'affili': 157, 'afford': 158, 'afg': 159, 'afghan': 160, 'afghanistan': 161, 'afl': 162, 'afloat': 163, 'afneil': 164, 'afp': 165, 'afraid': 166, "africa'": 167, 'africacdc': 168, 'africaday': 169, 'african': 170, 'africanunion': 171, 'aftermath': 172, 'afternoon': 173, 'afthunderbird': 174, 'ag': 175, 'agar': 176, 'age': 177, 'agenc': 178, 'agenda': 179, 'agent': 180, 'aggress': 181, 'agil': 182, 'agm': 183, 'agp': 184, 'agra': 185, 'agre': 186, 'agreement': 187, 'agri': 188, 'agricultur': 189, 'ahh': 190, 'ahhh': 191, 'ahm': 192, 'ahmedabad': 193, 'aict': 194, 'aid': 195, 'aiim': 196, 'ail': 197, 'aim': 198, 'ain': 199, 'aint': 200, 'air': 201, 'air_pollution': 202, 'airbnb': 203, 'airborn': 204, 'airbu': 205, 'aircraft': 206, 'airforc': 207, 'airindia': 208, 'airindiain': 209, 'airlift': 210, 'airlin': 211, 'airnewsalert': 212, 'airplan': 213, 'airpollut': 214, 'airport': 215, 'airtel': 216, 'airway': 217, 'ait': 218, 'aja': 219, 'ajay': 220, 'ajc': 221, 'ajenew': 222, 'ajenglish': 223, 'ajitpawarspeak': 224, 'ajk': 225, 'aka': 226, 'akg': 227, 'akin': 228, 'ako': 229, 'akshay': 230, 'akshaykumar': 231, 'aku': 232, 'akufo-addo': 233, 'akwa': 234, 'al': 235, 'ala': 236, 'alabama': 237, 'alam': 238, 'alan': 239, 'alarabiya': 240, 'alarm': 241, 'alarmist': 242, 'alaska': 243, 'albeit': 244, 'albert': 245, 'alberta': 246, 'alberto': 247, 'albomp': 248, 'album': 249, 'alcohol': 250, 'alcohol-bas': 251, 'alert': 252, 'alex': 253, 'alexa': 254, 'alexand': 255, 'alexberenson': 256, 'algorithm': 257, 'alhamdulillah': 258, 'ali': 259, 'alibaba': 260, 'alibabagroup': 261, 'alic': 262, 'alien': 263, 'align': 264, 'alik': 265, 'alistairhaim': 266, 'aliv': 267, 'aljazeera': 268, 'all-tim': 269, 'allah': 2 ...

# %% [markdown]
# ## Outputting vocab into a file

# %%
#outputting vocab into a file


out_file = open("./31043313_vocab.txt", 'w')

for i in vocab_dict.keys():
    out_file.write(str(i) + ':' + str(vocab_dict[i]) + '\n')
out_file.close()

# %% [markdown]
# ## Unigram - workings

# %%
#workings for the unigram section

from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.probability import FreqDist


#tokenizing by date

zdict = {}

for key in dict1.keys():
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
    tokens = tokenizer.tokenize(str(dict1[key]).lower())  #.lower()
    zdict[key] = tokens




    
#removing context independant stopwords  

for date in zdict.keys():
    zdict[date]=[token for token in zdict[date] if token not in stopwords]


#stemming
for date in zdict.keys():
    stem_words = ['{1}'.format(u, stemmer.stem(u)) for u in zdict[date]]
    
    stem_words = list(stem_words)
    stem_words.sort()
    zdict[date] = stem_words
    
#removing words lenth less than 3  
for i in zdict.keys():
    zdict[i]=[token for token in zdict[i] if len(token)>=3]
    
    
# top 100 most common unigrams    
for i in zdict.keys():
    zdict[i] = FreqDist(zdict[i]).most_common(100)

# %%
zdict['2020-03-22']
# Out:
# [('http', 865),
#  ('coronaviru', 384),
#  ('covid', 372),
#  ('peopl', 116),
#  ('nhttp', 90),
#  ('coronaviruspandem', 72),
#  ('case', 66),
#  ('test', 65),
#  ('time', 61),
#  ('amp', 46),
#  ('pandem', 43),
#  ('viru', 42),
#  ('countri', 41),
#  ('fight', 41),
#  ('india', 41),
#  ('stay', 39),
#  ('live', 38),
#  ('day', 36),
#  ('health', 36),
#  ('home', 36),
#  ('stop', 36),
#  ('trump', 35),
#  ('itali', 34),
#  ('news', 34),
#  ('support', 33),
#  ('spread', 32),
#  ('govern', 31),
#  ('world', 31),
#  ('make', 30),
#  ('outbreak', 27),
#  ('call', 26),
#  ('famili', 26),
#  ('friend', 26),
#  ('lockdown', 26),
#  ('presid', 26),
#  ('work', 26),
#  ('death', 25),
#  ('die', 25),
#  ('hospit', 25),
#  ('thing', 25),
#  ('crisi', 24),
#  ('respons', 24),
#  ('share', 24),
#  ('protect', 23),
#  ('public', 23),
#  ('china', 22),
#  ('good', 22),
#  ('posit', 22),
#  ('read', 22),
#  ('close', 21),
#  ('due', 21),
#  ('march', 21),
#  ('social', 21),
#  ('state', 21),
#  ('confirm', 20),
#  ('quarantin', 20),
#  ('care', 19),
#  ('corona', 19),
#  ('don', 19),
#  ('love', 19),
#  ('week', 19),
#  ('covidiot', 18),
#  ('diseas', 18),
#  ('isol', 18),
#  ('safe', 18),
#  ('year', 18),
#  ('curfew', 17),
#  ('hand', 17),
#  ('jantacurfew', 17),
#  ('mask', 17),
#  ('number', 17),
#  ('patient', 17),
#  ('put', 17),
#  ('realdonaldtrump', 17),
#  ('show', 17),
#  ('stand', 17),
#  ('commun', 16),
#  ('distanc', 16),
#  ('fuck', 16),
#  ('give', 16),
#  ('god', 16),
#  ('human', 16),
#  ('kill', 16),
#  ('provid', 16),
#  ('risk', 16),
#  ('sign', 16),
#  ('today', 16),
#  ('worker', 16),
#  ('act', 15),
#  ('lie', 15),
#  ('narendramodi', 15),
#  ('report', 15),
#  ('servic', 15),
#  ('updat', 15),
#  ('back', 14),
#  ('infect', 14),
#  ('inform', 14),
#  ('leader', 14),
#  ('listen', 14),
#  ('real', 14)]

# %% [markdown]
# ### Outputting 100uni into a file

# %%
#outputting 100uni into a file


out_file = open("./31043313_100uni.txt", 'w')
for d in zdict.keys():
    out_file.write(''.join(str(zdict[d])).replace('[',(d + ':[')) + '\n')
out_file.close()

# %% [markdown]
# ## Bigram - workings

# %%
#workings for bigram section
from nltk.util import ngrams

#tokenizing by date

bdict = {}

for key in dict1.keys():
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
    tokens = tokenizer.tokenize(str(dict1[key]).lower())  #.lower()
    bdict[key] = tokens


# top 100 most common bigrams
for i in bdict.keys():
    s = ngrams(bdict[i], n = 2)
    bdict[i] = FreqDist(s).most_common(100)

# %%
bdict['2020-03-24']
# Out:
# [(('t', 'co'), 1005),
#  (('https', 't'), 903),
#  (('nhttps', 't'), 102),
#  (('n', 'n'), 89),
#  (('the', 'coronavirus'), 67),
#  (('of', 'the'), 61),
#  (('n', 'nhttps'), 51),
#  (('in', 'the'), 49),
#  (('covid', 'https'), 42),
#  (('n', 'covid'), 33),
#  (('the', 'covid'), 33),
#  (('to', 'the'), 31),
#  (('this', 'is'), 31),
#  (('on', 'the'), 26),
#  (('for', 'the'), 26),
#  (('of', 'coronavirus'), 26),
#  (('coronavirus', 'https'), 26),
#  (('the', 'world'), 26),
#  (('is', 'a'), 26),
#  (('coronavirus', 'covid'), 25),
#  (('from', 'the'), 24),
#  (('will', 'be'), 23),
#  (('due', 'to'), 23),
#  (('we', 'are'), 22),
#  (('coronavirus', 'outbreak'), 21),
#  (('at', 'home'), 21),
#  (('to', 'be'), 20),
#  (('if', 'you'), 20),
#  (('of', 'covid'), 19),
#  (('to', 'covid'), 19),
#  (('we', 'have'), 18),
#  (('n', 'coronavirus'), 18),
#  (('covid', 'covid'), 18),
#  (('covid', 'n'), 18),
#  (('is', 'the'), 18),
#  (('during', 'the'), 17),
#  (('coronavirus', 'pandemic'), 17),
#  (('it', 's'), 17),
#  (('in', 'a'), 17),
#  (('you', 'are'), 17),
#  (('you', 'can'), 17),
#  (('as', 'a'), 16),
#  (('at', 'the'), 15),
#  (('number', 'of'), 15),
#  (('spread', 'of'), 15),
#  (('have', 'been'), 15),
#  (('to', 'get'), 15),
#  (('social', 'distancing'), 14),
#  (('coronavirus', 'cases'), 14),
#  (('the', 'spread'), 14),
#  (('u', 's'), 14),
#  (('stay', 'at'), 14),
#  (('want', 'to'), 14),
#  (('with', 'the'), 14),
#  (('for', 'covid'), 14),
#  (('is', 'not'), 13),
#  (('i', 'm'), 13),
#  (('should', 'be'), 12),
#  (('the', 'virus'), 12),
#  (('of', 'us'), 12),
#  (('covid', 'pandemic'), 12),
#  (('covid', 'coronavirus'), 12),
#  (('sign', 'the'), 12),
#  (('to', 'do'), 12),
#  (('cases', 'in'), 12),
#  (('coronavirus', 'in'), 11),
#  (('to', 'work'), 11),
#  (('all', 'the'), 11),
#  (('one', 'of'), 11),
#  (('for', 'coronavirus'), 11),
#  (('of', 'a'), 11),
#  (('it', 'is'), 11),
#  (('it', 'https'), 11),
#  (('they', 'are'), 11),
#  (('there', 'are'), 11),
#  (('to', 'keep'), 11),
#  (('to', 'help'), 11),
#  (('that', 'we'), 11),
#  (('the', 'most'), 11),
#  (('n', 'https'), 11),
#  (('need', 'to'), 11),
#  (('to', 'coronavirus'), 11),
#  (('people', 'are'), 10),
#  (('covid', 'is'), 10),
#  (('in', 'this'), 10),
#  (('of', 'this'), 10),
#  (('be', 'a'), 10),
#  (('co', 'l'), 10),
#  (('do', 'you'), 10),
#  (('coronavirus', 'is'), 10),
#  (('stay', 'safe'), 10),
#  (('have', 'to'), 10),
#  (('about', 'the'), 10),
#  (('with', 'a'), 10),
#  (('has', 'been'), 10),
#  (('we', 'will'), 10),
#  (('covid', 'outbreak'), 10),
#  (('are', 'not'), 10),
#  (('the', 'petition'), 10),
#  (('n', 'nthe'), 9)]

# %% [markdown]
# ### Outputting 100bi into a file

# %%
#outputting 100bi into a file


out_file = open("./31043313_100bi.txt", 'w')
for d in bdict.keys():
    out_file.write(''.join(str(bdict[d])).replace('[',(d + ':[')) + '\n')
out_file.close()
