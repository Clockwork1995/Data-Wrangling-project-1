# %% [markdown]
# # Task 1: Parsing Text Files (%55)

# %% [markdown]
# ## Importing required libraries

# %%
import re
import os
import langid
import sys

# %% [markdown]
# ## For this part i read all the files for part 1 and compiled them into a text file called combined data

# %%
file_names = os.listdir(r'C:\\Users\\ClockworK\\Desktop\\fit5196\\Assignment 1\\sample output part 1/') 
output = '' 
for file in file_names: 
    with open('C:\\Users\\ClockworK\\Desktop\\fit5196\\Assignment 1\\sample output part 1\\'+file, encoding = 'utf8') as f: 
        content = f.read().strip('\n') 
    output += content + '\t0\n'   
    
#encode your string by using .encode()    
output = output.encode()
with open('SampleData', 'wb') as f: 
    f.write(output)

# %% [markdown]
# ## Here i searched through the combined data file to extract the ids, created_at and texts using regular expression

# %%
file = open('C:\\Users\\ClockworK\\Desktop\\fit5196\\Assignment 1\\'+'CombinedData.txt','r',encoding="utf8").read()

#ids
ids = re.findall(r'"id":"(\d{19})"', file)

#created_at

dates = re.findall(r'"created_at":"((?:(?:\d{2})?\d{2})[-](?:0?[1-9]|1[0-2])[-](?:0[1-9]|[12][0-9]|3[01]))', file)

#text

texts = re.findall(r'"text":"(.*?)"',file)

# %%
print(len(ids))
# Out:
# 213960

# %%
print(len(dates))
# Out:
# 213960

# %%
print(dates[1])
# Out:
# 2020-03-22

# %%
print(ids[0:5])
# Out:
# ['1241639679696326656', '1241639682561064960', '1241639683072897024', '1241639683156856832', '1241639683333009411']

# %%
print(texts[0])
# Out:
# IRS Issues High Deductible Health Plan Guidance Related to COVID-19 https://t.co/n9acLgRL3L | by @littler

# %% [markdown]
# ## For this step, i combined all the extractd data in a nested list format, where each nested list contains id text and date for each tweet.

# %%
#combining extracted data

id_text_date = []

for i in range(len(texts)):
    id_text_date.append([])
    id_text_date[i].append(ids[i])
    id_text_date[i].append(texts[i])
    id_text_date[i].append(dates[i])
    
print(id_text_date[0:2])
# Out:
# [['1241639679696326656', 'IRS Issues High Deductible Health Plan Guidance Related to COVID-19 https://t.co/n9acLgRL3L | by @littler', '2020-03-22'], ['1241639682561064960', 'Amazing: A shop owner performs rituals and worship lord at shop, and  demanded not to send persons, who have come in contect of novel coronavirus on #JantaCurfew in #Bhubaneswar.\\n@BBSRBuzz\\n@devasissarangi\\n\\n#JantaCurfewMarch22\\n#WarAgainstVirus \\n#JanataCurfewChallenge https://t.co/uIfT5zdV22', '2020-03-22']]

# %%
print(len(id_text_date))
# Out:
# 213960

# %% [markdown]
# ## Here i removed the duplicate lists in the nested list to remove repeated tweet instances

# %%
#removing duplicates

cleaned = list(set(tuple(i) for i in id_text_date)) 

print(len(cleaned))
# Out:
# 213902

# %%
print(cleaned[0])
# Out:
# ('1261215950524878848', 'Inquiétante augmentation des cas de Coronavirus au Togo https://t.co/PGGdPggMSi via @La voix de la nation', '2020-05-15')

# %% [markdown]
# ## To classify the tweets i used langid package iterating through each list and checking if language of the text is english and appending the english tweets into a new list.

# %%
#classify tweets 

#get only english tweets

liss = []

for i in range(len(cleaned)):
    if langid.classify(cleaned[i][1])[0] == 'en':
        liss.append(cleaned[i])



print(len(liss))
# Out:
# 124673

# %%
print(liss[0:10])
# Out:
# [('1247745189491273728', '@Tish_H_Warren Your parish might not be #1/#1 online, but easily in the top 10, if not final 4! One blessing of our #COVID19 journey is being able to be together virtually with other believers. We so love our home Rev 7 diverse @EastbrookChurch. Great to also visit CotA on a Sunday morning. https://t.co/GGMeYl8TKQ', '2020-04-08'), ('1263777965575409664', "@JulietMtombeni @MemoryMushore @MoHCCZim @GenHealthZW @zcphp @GreenfieldBots @MaishaHealthFnd @healthtimeszim @zim_health Covid-19 is real and is around, kungoti chete some people don't believe a Zimbo can be affected hameno kuti kudzungaira here or what", '2020-05-22'), ('1246033439431593985', '“I Lost My Husband to Covid-19 - Wake-Up Call - Medium” https://t.co/gW3tO3kyxF', '2020-04-03'), ('1251105342555119616', 'This is one of the many reasons why robust EIAs are so important - to foresee and prevent these kinds of unintentional discrimination https://t.co/XKI4dO2Fyg', '2020-04-17'), ('1267407706010214401', '@AP I Will Setup And Customize Your Facebook And Instagram Ads Campaign,If You Want To Grow You Business,then\\n\\nContract Here:\\nhttps://t.co/fqUrhsCbEU\\n\\n#100DaysOfCode #WomenWhoCode\\n#COVID19 #mondaythoughts #Facts #Facebook #BunkerDon #BlackLivesMatter #BostonProtests #bostonprotest', '2020-06-01'), ('1247076788993490944', 'Second in our series of analysis pieces on the longer-term policy implications of coronavirus - Louise Casey on how street homelessness is *always* a public health crisis https://t.co/uTPx9sfWlr', '2020-04-06'), ('1245256042398674944', 'A #Kashmiri political activist has flayed the #Pakistan government for raking up the #Kashmir issue at a time when the entire world is combating the #COVID19 outbreak. https://t.co/JzpBQ51z4a', '2020-04-01'), ('1259053708572348417', "#COVID19 #worldometer #VEDay75 8/5 update\\n\\n'Never despair\\nNever give up\\nWe will meet again'\\nPhased end to #lockdown\\nMaintain physical distancing\\nSupport one another\\nWash hands\\nUse #NHS when needed\\n#COVID19 will end eventually with vaccine https://t.co/bL1smZK6bA https://t.co/VNFKOm2LiX", '2020-05-09'), ('1260479250328584195', "Memo to Boris Johnson: if it's not yet safe to travel to work, it's not yet safe to return to work. https://t.co/znPLucHJ8N", '2020-05-13'), ('1258279516666916865', 'Let this sink in...\\nThe long term effects &amp; mental health impact of this continued shut-down far outway the impact of the ‘Coronavirus’ itself... https://t.co/4IDtZemLKb', '2020-05-07')]

# %%
langid.classify(id_text_date[10][1])
# Out:
# ('tr', -421.40981006622314)

# %%
print(id_text_date[10])
# Out:
# ['1241639687330152449', 'Coronavirus testleri herkese kolay eriştirilmeli ve sonuçları hastaya söylenmeli. Yoksa bu hastalığı en ağır geçiren ülke olacağız.  Bu sorumluluğun altında kalırsınız.', '2020-03-22']

# %%
print(liss[0:6])
# Out:
# [('1247745189491273728', '@Tish_H_Warren Your parish might not be #1/#1 online, but easily in the top 10, if not final 4! One blessing of our #COVID19 journey is being able to be together virtually with other believers. We so love our home Rev 7 diverse @EastbrookChurch. Great to also visit CotA on a Sunday morning. https://t.co/GGMeYl8TKQ', '2020-04-08'), ('1263777965575409664', "@JulietMtombeni @MemoryMushore @MoHCCZim @GenHealthZW @zcphp @GreenfieldBots @MaishaHealthFnd @healthtimeszim @zim_health Covid-19 is real and is around, kungoti chete some people don't believe a Zimbo can be affected hameno kuti kudzungaira here or what", '2020-05-22'), ('1246033439431593985', '“I Lost My Husband to Covid-19 - Wake-Up Call - Medium” https://t.co/gW3tO3kyxF', '2020-04-03'), ('1251105342555119616', 'This is one of the many reasons why robust EIAs are so important - to foresee and prevent these kinds of unintentional discrimination https://t.co/XKI4dO2Fyg', '2020-04-17'), ('1267407706010214401', '@AP I Will Setup And Customize Your Facebook And Instagram Ads Campaign,If You Want To Grow You Business,then\\n\\nContract Here:\\nhttps://t.co/fqUrhsCbEU\\n\\n#100DaysOfCode #WomenWhoCode\\n#COVID19 #mondaythoughts #Facts #Facebook #BunkerDon #BlackLivesMatter #BostonProtests #bostonprotest', '2020-06-01'), ('1247076788993490944', 'Second in our series of analysis pieces on the longer-term policy implications of coronavirus - Louise Casey on how street homelessness is *always* a public health crisis https://t.co/uTPx9sfWlr', '2020-04-06')]

# %% [markdown]
# ## A list containing all the unique dates

# %%
#number of unique dates

emp=[]
for i in liss:
    emp.append(i[2])
    
    
ass= list(set(emp))
print(ass)
# Out:
# ['2020-05-17', '2020-06-05', '2020-03-26', '2020-04-28', '2020-05-20', '2020-05-10', '2020-05-15', '2020-04-30', '2020-05-27', '2020-04-20', '2020-04-02', '2020-03-28', '2020-04-07', '2020-05-16', '2020-05-13', '2020-03-30', '2020-04-25', '2020-05-19', '2020-05-08', '2020-05-31', '2020-05-04', '2020-04-01', '2020-04-22', '2020-04-13', '2020-03-27', '2020-06-08', '2020-04-27', '2020-06-09', '2020-04-21', '2020-06-06', '2020-04-26', '2020-04-05', '2020-05-29', '2020-03-23', '2020-04-03', '2020-05-23', '2020-04-15', '2020-05-28', '2020-04-06', '2020-05-07', '2020-05-12', '2020-06-10', '2020-03-31', '2020-05-03', '2020-06-07', '2020-03-24', '2020-04-16', '2020-05-14', '2020-06-01', '2020-05-05', '2020-04-09', '2020-05-22', '2020-03-25', '2020-05-01', '2020-05-25', '2020-04-14', '2020-04-23', '2020-05-26', '2020-04-29', '2020-05-02', '2020-04-10', '2020-06-02', '2020-05-09', '2020-04-19', '2020-03-22', '2020-04-17', '2020-05-24', '2020-06-04', '2020-04-04', '2020-05-06', '2020-04-11', '2020-05-30', '2020-04-24', '2020-05-11', '2020-04-08', '2020-03-29', '2020-04-18', '2020-05-21', '2020-04-12', '2020-06-03', '2020-05-18']

# %% [markdown]
# ## Grouping all the tweets of same date as lists of list

# %%
# grouping tweets of same date as lists of list

num_lists = len(ass)
lists = []
for p in range(num_lists):
    lists.append([])


liss = list(liss)



for i in range(len(liss)):
    for k in range(len(ass)):
        if liss[i][2] == ass[k]:
            lists[k].append(liss[i])
        
        
print(len(lists[0]))
# Out:
# 1574

# %%
#checking if correct
z = 0

for i in range(len(lists)):
    z+= len(lists[i])
 

print(z)
# Out:
# 124673

# %% [markdown]
# ## This is a list of number of tweets for each date. this is useful later on.

# %%
z = []

for i in range(len(lists)):
    z.append(len(lists[i]))
 

print(z[0:4])
# Out:
# [1574, 1517, 1501, 1606]

# %% [markdown]
# ## Creating the required XML file and adding all the extracted data done above.

# %%
# creating xml file



f = open("31043313.xml", "w",encoding='utf-8')
f.write('<?xml version="1.0" encoding="UTF-8"?>')
f.write('\n<data>')

for i in range(len(ass)):
    k = ass[i]
    f.write(('\n<tweets' + ' ' + 'date=' + '"'+  k + '"' + '>'))
    
    fu = z[i]
    
    for m in range(fu):
        
        k = ass[i]
        f.write(('\n<tweet' + ' ' + 'id=' + '"' + lists[i][m][0] + '"' + '>'))
        
        if lists[i][m][2] == k:
            f.write(lists[i][m][1])
        f.write('\n</tweet>')
    
    
    f.write('\n</tweets>')

f.write('\n</data>')
f.close()

# %%
print(len(lists))
# Out:
# 81

# %%
print(lists[0][0][1])
# Out:
# Another day, another makeup guru controversy!\nOn Friday, Jeffree Star announced the launch of his latest palette via Instagram, and it definitely ruffled some feathers. https://t.co/DVlo6zMQML

# %%
print(lists[0][0][0])
# Out:
# 1261907900202655744

# %%
#rough work for task 2

# %%
# # reading excel file

# data = pd.ExcelFile('31043313.xlsx')
# df = []
# for sheet in data.sheet_names:
#     df.append(data.parse(sheet)
#                          .dropna(axis = 0, how ='all')
#                          .dropna(axis = 1, how ='all').T.reset_index(drop=True).T)
    
# df = pd.concat(df)

# df = df[df[0] != 'text']
# print(len(df))    
    
# df.columns = ['text', 'id', 'created_at']


# #reset dataframe index

# df = df.reset_index(drop=True)

# df.head()
# Out:
# 162000
#                                                 text                   id  \
# 0  These are tough times, the president has to ad...  1241652580637344000
# 1               @OosiTappasu https://t.co/OOQXC15j6q  1241727281749344000
# 2  We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 3  En serio, el Gobierno y todos sus ministerios ...  1241637670788488960
# 4  An open letter - signed by cca. 1000 scholars ...  1241712869894430976
#
#                  created_at
# 0  2020-03-22T09:06:58.000Z
# 1  2020-03-22T14:03:48.000Z
# 2  2020-03-22T05:18:45.000Z
# 3  2020-03-22T08:07:43.000Z
# 4  2020-03-22T13:06:32.000Z

# %%
# #classifying the dataframe using langid, keeping only the english tweets

# df = df.head(50)
# for i in range(len(df['text'])):
#     if langid.classify(str(df['text'][i]))[0] != 'en':
#         df=df.drop([i])
        
# print(len(df))
# Out:
# 27

# %%
# df.head(27)
# Out:
#                                                  text                   id  \
# 0   These are tough times, the president has to ad...  1241652580637344000
# 2   We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 4   An open letter - signed by cca. 1000 scholars ...  1241712869894430976
# 7   Please remember each time you choose to buy si...  1241687033485168896
# 8   The people of India have decided- we are in th...  1241633333383172096
# 10  As COVID-19 Drives People Into Isolation, Wall...  1241710080304614912
# 12  ‘The separation of health and environmental po...  1241663385894339072
# 13  Mr. President, Follow the South Korean Model t...  1241692430786653952
# 14  The Scientific Detectives Tracing Coronavirus ...  1241711452202861056
# 17  @realDonaldTrump It's the novel coronavirus or...  1241745153385168896
# 20  @KLemberg @Drewdferguson @BongoMaggie @Kookied...  1241664245202406912
# 22  People are waking up. But possibly not before ...  1241622449042711040
# 24  More deaths than recoveries 😲 https://t.co/oGF...  1241617189549093120
# 25  @RonaldKlain is a superb expert to consult wit...  1241627398434459904
# 26  Asim Azhar finds a ‘medicine’ for coronavirus ...  1241619132472267008
# 27  For more information, please go to our COVID-1...  1241720138442969088
# 30  Petition: Implement UK lockdown for preventing...  1241685996900670976
# 34  I pray everyone that goes to church today dies...  1241638992321413120
# 35  Come and see Mamukokoot's LIVE in #BIGOLIVE: K...  1241605860654084096
# 36  How did Bill Gates &amp; his Netflix Pandemic ...  1241617885799354112
# 38  Enormous thanks &amp; respect to Dentaa Amoate...  1241711242617795072
# 39  #coronavirus\n\n"Critical Medical Supply Short...  1241737201219777024
# 42  Some useful ideas on how to survive being at h...  1241734352842691072
# 43  @ThelmaChen @FreedomFreddy55 I don’t know abou...  1241704544104579072
# 47  This COVID19 is very real people please take i...  1241721317159768064
# 48     Sunday morning scaries https://t.co/JgHXeVLPFK  1241714052281310976
# 49  It really took the coronavirus for millennials...  1241576135604888064
#
#                   created_at
# 0   2020-03-22T09:06:58.000Z
# 2   2020-03-22T05:18:45.000Z
# 4   2020-03-22T13:06:32.000Z
# 7   2020-03-22T11:23:52.000Z
# 8   2020-03-22T07:50:29.000Z
# 10  2020-03-22T12:55:27.000Z
# 12  2020-03-22T09:49:54.000Z
# 13  2020-03-22T11:45:19.000Z
# 14  2020-03-22T13:00:54.000Z
# 17  2020-03-22T15:14:49.000Z
# 20  2020-03-22T09:53:19.000Z
# 22  2020-03-22T07:07:14.000Z
# 24  2020-03-22T06:46:20.000Z
# 25  2020-03-22T07:26:54.000Z
# 26  2020-03-22T06:54:04.000Z
# 27  2020-03-22T13:35:25.000Z
# 30  2020-03-22T11:19:45.000Z
# 34  2020-03-22T08:12:58.000Z
# 35  2020-03-22T06:01:19.000Z
# 36  2020-03-22T06:49:06.000Z
# 38  2020-03-22T13:00:04.000Z
# 39  2020-03-22T14:43:13.000Z
# 42  2020-03-22T14:31:54.000Z
# 43  2020-03-22T12:33:27.000Z
# 47  2020-03-22T13:40:06.000Z
# 48  2020-03-22T13:11:14.000Z
# 49  2020-03-22T04:03:12.000Z

# %%
# df[['created_at','k']] = df['created_at'].str.split('T',expand=True)

# %%
# df = df.drop(columns = ['k'])
# df
# Out:
#                                                  text                   id  \
# 0   These are tough times, the president has to ad...  1241652580637344000
# 2   We have a Lieutenant Governor, GC Murmu who is...  1241595147655056896
# 4   An open letter - signed by cca. 1000 scholars ...  1241712869894430976
# 7   Please remember each time you choose to buy si...  1241687033485168896
# 8   The people of India have decided- we are in th...  1241633333383172096
# 10  As COVID-19 Drives People Into Isolation, Wall...  1241710080304614912
# 12  ‘The separation of health and environmental po...  1241663385894339072
# 13  Mr. President, Follow the South Korean Model t...  1241692430786653952
# 14  The Scientific Detectives Tracing Coronavirus ...  1241711452202861056
# 17  @realDonaldTrump It's the novel coronavirus or...  1241745153385168896
# 20  @KLemberg @Drewdferguson @BongoMaggie @Kookied...  1241664245202406912
# 22  People are waking up. But possibly not before ...  1241622449042711040
# 24  More deaths than recoveries 😲 https://t.co/oGF...  1241617189549093120
# 25  @RonaldKlain is a superb expert to consult wit...  1241627398434459904
# 26  Asim Azhar finds a ‘medicine’ for coronavirus ...  1241619132472267008
# 27  For more information, please go to our COVID-1...  1241720138442969088
# 30  Petition: Implement UK lockdown for preventing...  1241685996900670976
# 34  I pray everyone that goes to church today dies...  1241638992321413120
# 35  Come and see Mamukokoot's LIVE in #BIGOLIVE: K...  1241605860654084096
# 36  How did Bill Gates &amp; his Netflix Pandemic ...  1241617885799354112
# 38  Enormous thanks &amp; respect to Dentaa Amoate...  1241711242617795072
# 39  #coronavirus\n\n"Critical Medical Supply Short...  1241737201219777024
# 42  Some useful ideas on how to survive being at h...  1241734352842691072
# 43  @ThelmaChen @FreedomFreddy55 I don’t know abou...  1241704544104579072
# 47  This COVID19 is very real people please take i...  1241721317159768064
# 48     Sunday morning scaries https://t.co/JgHXeVLPFK  1241714052281310976
# 49  It really took the coronavirus for millennials...  1241576135604888064
#
#     created_at
# 0   2020-03-22
# 2   2020-03-22
# 4   2020-03-22
# 7   2020-03-22
# 8   2020-03-22
# 10  2020-03-22
# 12  2020-03-22
# 13  2020-03-22
# 14  2020-03-22
# 17  2020-03-22
# 20  2020-03-22
# 22  2020-03-22
# 24  2020-03-22
# 25  2020-03-22
# 26  2020-03-22
# 27  2020-03-22
# 30  2020-03-22
# 34  2020-03-22
# 35  2020-03-22
# 36  2020-03-22
# 38  2020-03-22
# 39  2020-03-22
# 42  2020-03-22
# 43  2020-03-22
# 47  2020-03-22
# 48  2020-03-22
# 49  2020-03-22

# %%
# d1 = df.groupby('created_at')['id'].apply(list).to_dict()
# d2 = df.groupby('created_at')['text'].apply(list).to_dict()


# print(d2)
# Out:
# {'2020-03-22': ['These are tough times, the president has to address the nation twice a week. https://t.co/PUQBOd2QuQ', 'We have a Lieutenant Governor, GC Murmu who is personally out in the field for the sake of  people.\nAnd, we have a Chief Secretary who formally banned public entry into his office.\nThe tale of two offices.\n#MJH\n#Kashmir\n#CoronavirusPandemic \n#CoronaVirusUpdate \n#COVIDー19 https://t.co/N2sAnfbFec', 'An open letter - signed by cca. 1000 scholars til now - is currently circulating around German academia:\n\nGiven the public health crisis, the upcoming summer semester should not be treated as business-as-usual supported by technology. \n\nInstead, we ask for a #Nichtsemester ⬇️ https://t.co/gfeyFjYlEF', 'Please remember each time you choose to buy single use plastics like @Fullgreen_News use, you are polluting the planet for your children and their children. Dont be fooled by their #coronavirus help promotions. @Fullgreen_News pollution is ruining the planet.', 'The people of India have decided- we are in this together. We will fight the menace of COVID-19 together. #JantaCurfew https://t.co/1FlDQ3kevE', "As COVID-19 Drives People Into Isolation, Wall Street's New 'Virtual Workplace' May Become The Norm  https://t.co/sAsf7FBMQo", '‘The separation of health and environmental policy is a dangerous delusion. Our health depends on the climate and the other organisms we share the planet with. We need to bring these communities together’ Coronavirus, climate change, and the environment https://t.co/DcuZCOUzoh', 'Mr. President, Follow the South Korean Model to Defeat the Coronavirus https://t.co/E86Iarj81H', 'The Scientific Detectives Tracing Coronavirus https://t.co/vgov2valTf', '@realDonaldTrump It\'s the novel coronavirus or COVID-19. Stop calling it the "Chinese virus"', '@KLemberg @Drewdferguson @BongoMaggie @Kookieduck If you think that’s scary, @SenateGOP was aware of the coronavirus threat when they voted to acquit trump.', 'People are waking up. But possibly not before driving the country into a depression (while not even effectively addressing the virus issue). Please read it @GavinNewsom @NYGovCuomo @GovMurphy @GovRonDeSantis @GovernorTomWolf and also the WSJ item https://t.co/1eZw66yM4W\n\n👀 https://t.co/USVIE95XcU', 'More deaths than recoveries 😲 https://t.co/oGFjzfxobv', '@RonaldKlain is a superb expert to consult with on this COVID-19 situation.....good move @JoeBiden https://t.co/bcesQYaM3l', 'Asim Azhar finds a ‘medicine’ for coronavirus https://t.co/mBkOkh3mCr #Pakistan #News', 'For more information, please go to our COVID-19 information page at https://t.co/ODG26qN36f https://t.co/56jOZNdlVX', 'Petition: Implement UK lockdown for preventing spread of COVID19 https://t.co/mHsb5C5qmg', 'I pray everyone that goes to church today dies from Coronavirus. You cannot possibly be so irresponsible and still be looking for sympathy 😒', "Come and see Mamukokoot's LIVE in #BIGOLIVE: KWSP COVID19  \nhttps://t.co/9CmsrulzR4 https://t.co/CP0GmRcEOU", 'How did Bill Gates &amp; his Netflix Pandemic know the CoronaVirus was coming?\nSome say he funded it.\nMakes you think bigger picture https://t.co/YGAhhZyDMx', 'Enormous thanks &amp; respect to Dentaa Amoateng @Dentaa_show, queen of the British-Ghanaian community, who has voluntarily returned to her old job as a nurse at the Royal Free Hospital to treat #coronavirus patients.\nOutstanding, superb, humbling  #COVID19 #covid19Canada Retweet’s', '#coronavirus\n\n"Critical Medical Supply Shortage":\nThe Moment US Woke Up To Disaster Of Always Outsourcing To #China\nhttps://t.co/qtrtjuUv6X', 'Some useful ideas on how to survive being at home. https://t.co/evPir6XJ9F', '@ThelmaChen @FreedomFreddy55 I don’t know about you but I would rather this virus kill me than to live in fear. #COVIDIOT #QuaratineLife #QuarantineActivities #lockdown #COVID19', 'This COVID19 is very real people please take it seriously -👩🏼\u200d⚕️', 'Sunday morning scaries https://t.co/JgHXeVLPFK',  ...

# %%
# from nltk.tokenize import RegexpTokenizer

# %%
# #newlist = [word for line in d2['2020-03-22'] for word in line.split()]
# tokenizer = RegexpTokenizer(r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?")
# tokens = tokenizer.tokenize(str(d2['2020-03-22']))

# len(tokens)
# tokens
# Out:
# ['These',
#  'are',
#  'tough',
#  'times',
#  'the',
#  'president',
#  'has',
#  'to',
#  'address',
#  'the',
#  'nation',
#  'twice',
#  'a',
#  'week',
#  'https',
#  't',
#  'co',
#  'PUQBOd',
#  'QuQ',
#  'We',
#  'have',
#  'a',
#  'Lieutenant',
#  'Governor',
#  'GC',
#  'Murmu',
#  'who',
#  'is',
#  'personally',
#  'out',
#  'in',
#  'the',
#  'field',
#  'for',
#  'the',
#  'sake',
#  'of',
#  'people',
#  'nAnd',
#  'we',
#  'have',
#  'a',
#  'Chief',
#  'Secretary',
#  'who',
#  'formally',
#  'banned',
#  'public',
#  'entry',
#  'into',
#  'his',
#  'office',
#  'nThe',
#  'tale',
#  'of',
#  'two',
#  'offices',
#  'n',
#  'MJH',
#  'n',
#  'Kashmir',
#  'n',
#  'CoronavirusPandemic',
#  'n',
#  'CoronaVirusUpdate',
#  'n',
#  'COVID',
#  'https',
#  't',
#  'co',
#  'N',
#  'sAnfbFec',
#  'An',
#  'open',
#  'letter',
#  'signed',
#  'by',
#  'cca',
#  'scholars',
#  'til',
#  'now',
#  'is',
#  'currently',
#  'circulating',
#  'around',
#  'German',
#  'academia',
#  'n',
#  'nGiven',
#  'the',
#  'public',
#  'health',
#  'crisis',
#  'the',
#  'upcoming',
#  'summer',
#  'semester',
#  'should',
#  'not',
#  'be',
#  'treated',
#  'as',
#  'business-as',
#  'usual',
#  'supported',
#  'by',
#  'technology',
#  'n',
#  'nInstead',
#  'we',
#  'ask',
#  'for',
#  'a',
#  'Nichtsemester',
#  'https',
#  't',
#  'co',
#  'gfeyFjYlEF',
#  'Please',
#  'remember',
#  'each',
#  'time',
#  'you',
#  'choose',
#  'to',
#  'buy',
#  'single',
#  'use',
#  'plastics',
#  'like',
#  'Fullgreen',
#  'News',
#  'use',
#  'you',
#  'are',
#  'polluting',
#  'the',
#  'planet',
#  'for',
#  'your',
#  'children',
#  'and',
#  'their',
#  'children',
#  'Dont',
#  'be',
#  'fooled',
#  'by',
#  'their',
#  'coronavirus',
#  'help',
#  'promotions',
#  'Fullgreen',
#  'News',
#  'pollution',
#  'is',
#  'ruining',
#  'the',
#  'planet',
#  'The',
#  'people',
#  'of',
#  'India',
#  'have',
#  'decided',
#  'we',
#  'are',
#  'in',
#  'this',
#  'together',
#  'We',
#  'will',
#  'fight',
#  'the',
#  'menace',
#  'of',
#  'COVID',
#  'together',
#  'JantaCurfew',
#  'https',
#  't',
#  'co',
#  'FlDQ',
#  'kevE',
#  'As',
#  'COVID',
#  'Drives',
#  'People',
#  'Into',
#  'Isolation',
#  'Wall',
#  "Street's",
#  'New',
#  'Virtual',
#  'Workplace',
#  'May',
#  'Become',
#  'The',
#  'Norm',
#  'https',
#  't',
#  'co',
#  'sAsf',
#  'FBMQo',
#  'The',
#  'separation',
#  'of',
#  'health',
#  'and',
#  'environmental',
#  'policy',
#  'is',
#  'a',
#  'dangerous',
#  'delusion',
#  'Our',
#  'health',
#  'depends',
#  'on',
#  'the',
#  'climate',
#  'and',
#  'the',
#  'other',
#  'organisms',
#  'we',
#  'share',
#  'the',
#  'planet',
#  'with',
#  'We',
#  'need',
#  'to',
#  'bring',
#  'these',
#  'communities',
#  'together',
#  'Coronavirus',
#  'climate',
#  'change',
#  'and',
#  'the',
#  'environment',
#  'https',
#  't',
#  'co',
#  'DcuZCOUzoh',
#  'Mr',
#  'President',
#  'Follow',
#  'the',
#  'South',
#  'Korean',
#  'Model',
#  'to',
#  'Defeat',
#  'the',
#  'Coronavirus',
#  'https',
#  't',
#  'co',
#  'E',
#  'Iarj',
#  'H',
#  'The',
#  'Scientific',
#  'Detectives',
#  'Tracing',
#  'Coronavirus',
#  'https',
#  't',
#  'co',
#  'vgov',
#  'valTf',
#  'realDonaldTrump',
#  'It',
#  's',
#  'the',
#  'novel',
#  'coronavirus',
#  'or',
#  'COVID',
#  'Stop',
#  'calling',
#  'it',
#  'the',
#  'Chinese',
#  'virus',
#  'KLemberg',
#  'Drewdferguson',
#  'BongoMaggie',
#  'Kookieduck',
#  'If',
#  'you',
#  'think',
#  'that',
#  's',
#  'scary',
#  'SenateGOP',
#  'was',
#  'aware',
#  'of',
#  'the',
#  'coronavirus',
#  'threat',
#  'when',
#  'they',
#  'voted',
#  'to',
#  'acquit',
#  'trump',
#  'People',
#  'are',
#  'waking',
#  'up',
#  'But',
#  'possibly',
#  'not',
#  'before',
#  'driving',
#  'the',
#  'country',
#  'into',
#  'a',
#  'depression',
#  'while',
#  'not',
#  'even',
#  'effectively',
#  'addressing',
#  'the',
#  'virus',
#  'issue',
#  'Please',
#  'read',
#  'it',
#  'GavinNewsom',
#  'NYGovCuomo',
#  'GovMurphy',
#  'GovRonDeSantis',
#  'GovernorTomWolf',
#  'and',
#  'also',
#  'the',
#  'WSJ',
#  'item',
#  'https',
#  't',
#  'co',
#  'eZw',
#  'yM',
#  'W',
#  'n',
#  'n',
#  'https',
#  't',
#  'co',
#  'USVIE',
#  'XcU',
#  'More',
#  'deaths',
#  'than',
#  'recoveries',
#  'https',
#  't',
#  'co',
#  'oGFjzfxobv',
#  'RonaldKlain',
#  'is',
#  'a',
#  'superb',
#  'expert',
#  'to',
#  'consult',
#  'with',
#  'on',
#  'this',
#  'COVID',
#  'situation',
#  'good',
#  'move',
#  'JoeBiden',
#  'https',
#  't',
#  'co',
#  'bcesQYaM',
#  'l',
#  'Asim',
#  'Azhar',
#  'finds',
#  'a',
#  'medicine',
#  'for',
#  'coronavirus',
#  'https',
#  't',
#  'co',
#  'mBkOkh',
#  'mCr',
#  'Pakistan',
#  'News',
#  'For',
#  'more',
#  'information',
#  'please',
#  'go',
#  'to',
#  'our',
#  'COVID',
#  'information',
#  'page',
#  'at',
#  'https',
#  't',
#  'co',
#  'ODG',
#  'qN',
#  'f',
#  'https',
#  't',
#  'co',
#  'jOZNdlVX',
#  'Petition',
#  'Implement',
#  'UK',
#  'lockdown',
#  'for',
#  'preventing',
#  'spread',
#  'of',
#  'COVID',
#  'https',
#  't',
#  'co',
#  'mHsb',
#  'C',
#  'qmg',
#  'I',
#  'pray',
#  'everyone',
#  'that',
#  'goes',
#  'to',
#  'church',
#  'today',
#  'dies',
#  'from',
#  'Coronavirus',
#  'You',
#  'cannot',
#  'possibly',
#  'be',
#  'so',
#  'irresponsible',
#  'and',
#  'still',
#  'be',
#  'looking',
#  'for',
#  'sympathy',
#  'Come',
#  'and',
#  'see',
#  "Mamukokoot's",
#  'LIVE',
#  'in',
#  'BIGOLIVE',
#  'KWSP',
#  'COVID',
#  'nhttps',
#  't',
#  'co',
#  'CmsrulzR',
#  'https',
#  't',
#  'co',
#  'CP',
#  'GmRcEOU',
#  'How',
#  'did',
#  'Bill',
#  'Gates',
#  'amp',
#  'his',
#  'Netflix',
#  'Pandemic',
#  'know',
#  'the',
#  'CoronaVirus',
#  'was',
#  'coming',
#  'nSome',
#  'say',
#  'he',
#  'funded',
#  'it',
#  'nMakes',
#  'you',
#  'think',
#  'bigger',
#  'picture',
#  'https',
#  't',
#  'co',
#  'YGAhhZyDMx',
#  'Enormous',
#  'thanks',
#  'amp',
#  'respect',
#  'to',
#  'Dentaa',
#  'Amoateng',
#  'Dentaa',
#  'show',
#  'queen',
#  'of',
#  'the',
#  'British-Ghanaian',
#  'community',
#  'who',
#  'has',
#  'voluntarily',
#  'returned',
#  'to',
#  'her',
#  'old',
#  'job',
#  'as',
#  'a',
#  'nurse',
#  'at',
#  'the',
#  'Royal',
#  'Free',
#  'Hospital',
#  'to',
#  'treat',
#  'coronavirus',
#  'patients',
#  'nOutstanding',
#  'superb',
#  'humbling',
#  'COVID',
#  'covid',
#  'Canada',
#  'Retweet',
#  's',
#  'coronavirus',
#  'n',
#  'n',
#  'Critical',
#  'Medical',
#  'Supply',
#  'Shortage',
#  'nThe',
#  'Moment',
#  'US',
#  'Woke',
#  'Up',
#  'To',
#  'Disaster',
#  'Of',
#  'Always',
#  'Outsourcing',
#  'To',
#  'China',
#  'nhttps',
#  't',
#  'co',
#  'qtrtjuUv',
#  'X',
#  'Some',
#  'useful',
#  'ideas',
#  'on',
#  'how',
#  'to',
#  'survive',
#  'being',
#  'at',
#  'home',
#  'https',
#  't',
#  'co',
#  'evPir',
#  'XJ',
#  'F',
#  'ThelmaChen',
#  'FreedomFreddy',
#  'I',
#  'don',
#  't',
#  'know',
#  'about',
#  'you',
#  'but',
#  'I',
#  'would',
#  'rather',
#  'this',
#  'virus',
#  'kill',
#  'me',
#  'than',
#  'to',
#  'live',
#  'in',
#  'fear',
#  'COVIDIOT',
#  'QuaratineLife',
#  'QuarantineActivities',
#  'lockdown',
#  'COVID',
#  'This',
#  'COVID',
#  'is',
#  'very',
#  'real',
#  'people',
#  'please',
#  'take',
#  'it',
#  'seriously',
#  'u',
#  'd',
#  'Sunday',
#  'morning',
#  'scaries',
#  'https',
#  't',
#  'co',
#  'JgHXeVLPFK',
#  'It',
#  'really',
#  'took',
#  'the',
#  'coronavirus',
#  'for',
#  'millennials',
#  'to',
#  'throw',
#  'gen',
#  'z',
#  'under',
#  'the',
#  'bus']

# %%
    
# newlist = [word for line in d2['2020-03-22'] for word in line.split()]

# %%
newlist
# Out:
# ['These',
#  'are',
#  'tough',
#  'times,',
#  'the',
#  'president',
#  'has',
#  'to',
#  'address',
#  'the',
#  'nation',
#  'twice',
#  'a',
#  'week.',
#  'https://t.co/PUQBOd2QuQ',
#  'We',
#  'have',
#  'a',
#  'Lieutenant',
#  'Governor,',
#  'GC',
#  'Murmu',
#  'who',
#  'is',
#  'personally',
#  'out',
#  'in',
#  'the',
#  'field',
#  'for',
#  'the',
#  'sake',
#  'of',
#  'people.',
#  'And,',
#  'we',
#  'have',
#  'a',
#  'Chief',
#  'Secretary',
#  'who',
#  'formally',
#  'banned',
#  'public',
#  'entry',
#  'into',
#  'his',
#  'office.',
#  'The',
#  'tale',
#  'of',
#  'two',
#  'offices.',
#  '#MJH',
#  '#Kashmir',
#  '#CoronavirusPandemic',
#  '#CoronaVirusUpdate',
#  '#COVIDー19',
#  'https://t.co/N2sAnfbFec',
#  'An',
#  'open',
#  'letter',
#  '-',
#  'signed',
#  'by',
#  'cca.',
#  '1000',
#  'scholars',
#  'til',
#  'now',
#  '-',
#  'is',
#  'currently',
#  'circulating',
#  'around',
#  'German',
#  'academia:',
#  'Given',
#  'the',
#  'public',
#  'health',
#  'crisis,',
#  'the',
#  'upcoming',
#  'summer',
#  'semester',
#  'should',
#  'not',
#  'be',
#  'treated',
#  'as',
#  'business-as-usual',
#  'supported',
#  'by',
#  'technology.',
#  'Instead,',
#  'we',
#  'ask',
#  'for',
#  'a',
#  '#Nichtsemester',
#  '⬇️',
#  'https://t.co/gfeyFjYlEF',
#  'Please',
#  'remember',
#  'each',
#  'time',
#  'you',
#  'choose',
#  'to',
#  'buy',
#  'single',
#  'use',
#  'plastics',
#  'like',
#  '@Fullgreen_News',
#  'use,',
#  'you',
#  'are',
#  'polluting',
#  'the',
#  'planet',
#  'for',
#  'your',
#  'children',
#  'and',
#  'their',
#  'children.',
#  'Dont',
#  'be',
#  'fooled',
#  'by',
#  'their',
#  '#coronavirus',
#  'help',
#  'promotions.',
#  '@Fullgreen_News',
#  'pollution',
#  'is',
#  'ruining',
#  'the',
#  'planet.',
#  'The',
#  'people',
#  'of',
#  'India',
#  'have',
#  'decided-',
#  'we',
#  'are',
#  'in',
#  'this',
#  'together.',
#  'We',
#  'will',
#  'fight',
#  'the',
#  'menace',
#  'of',
#  'COVID-19',
#  'together.',
#  '#JantaCurfew',
#  'https://t.co/1FlDQ3kevE',
#  'As',
#  'COVID-19',
#  'Drives',
#  'People',
#  'Into',
#  'Isolation,',
#  'Wall',
#  "Street's",
#  'New',
#  "'Virtual",
#  "Workplace'",
#  'May',
#  'Become',
#  'The',
#  'Norm',
#  'https://t.co/sAsf7FBMQo',
#  '‘The',
#  'separation',
#  'of',
#  'health',
#  'and',
#  'environmental',
#  'policy',
#  'is',
#  'a',
#  'dangerous',
#  'delusion.',
#  'Our',
#  'health',
#  'depends',
#  'on',
#  'the',
#  'climate',
#  'and',
#  'the',
#  'other',
#  'organisms',
#  'we',
#  'share',
#  'the',
#  'planet',
#  'with.',
#  'We',
#  'need',
#  'to',
#  'bring',
#  'these',
#  'communities',
#  'together’',
#  'Coronavirus,',
#  'climate',
#  'change,',
#  'and',
#  'the',
#  'environment',
#  'https://t.co/DcuZCOUzoh',
#  'Mr.',
#  'President,',
#  'Follow',
#  'the',
#  'South',
#  'Korean',
#  'Model',
#  'to',
#  'Defeat',
#  'the',
#  'Coronavirus',
#  'https://t.co/E86Iarj81H',
#  'The',
#  'Scientific',
#  'Detectives',
#  'Tracing',
#  'Coronavirus',
#  'https://t.co/vgov2valTf',
#  '@realDonaldTrump',
#  "It's",
#  'the',
#  'novel',
#  'coronavirus',
#  'or',
#  'COVID-19.',
#  'Stop',
#  'calling',
#  'it',
#  'the',
#  '"Chinese',
#  'virus"',
#  '@KLemberg',
#  '@Drewdferguson',
#  '@BongoMaggie',
#  '@Kookieduck',
#  'If',
#  'you',
#  'think',
#  'that’s',
#  'scary,',
#  '@SenateGOP',
#  'was',
#  'aware',
#  'of',
#  'the',
#  'coronavirus',
#  'threat',
#  'when',
#  'they',
#  'voted',
#  'to',
#  'acquit',
#  'trump.',
#  'People',
#  'are',
#  'waking',
#  'up.',
#  'But',
#  'possibly',
#  'not',
#  'before',
#  'driving',
#  'the',
#  'country',
#  'into',
#  'a',
#  'depression',
#  '(while',
#  'not',
#  'even',
#  'effectively',
#  'addressing',
#  'the',
#  'virus',
#  'issue).',
#  'Please',
#  'read',
#  'it',
#  '@GavinNewsom',
#  '@NYGovCuomo',
#  '@GovMurphy',
#  '@GovRonDeSantis',
#  '@GovernorTomWolf',
#  'and',
#  'also',
#  'the',
#  'WSJ',
#  'item',
#  'https://t.co/1eZw66yM4W',
#  '👀',
#  'https://t.co/USVIE95XcU',
#  'More',
#  'deaths',
#  'than',
#  'recoveries',
#  '😲',
#  'https://t.co/oGFjzfxobv',
#  '@RonaldKlain',
#  'is',
#  'a',
#  'superb',
#  'expert',
#  'to',
#  'consult',
#  'with',
#  'on',
#  'this',
#  'COVID-19',
#  'situation.....good',
#  'move',
#  '@JoeBiden',
#  'https://t.co/bcesQYaM3l',
#  'Asim',
#  'Azhar',
#  'finds',
#  'a',
#  '‘medicine’',
#  'for',
#  'coronavirus',
#  'https://t.co/mBkOkh3mCr',
#  '#Pakistan',
#  '#News',
#  'For',
#  'more',
#  'information,',
#  'please',
#  'go',
#  'to',
#  'our',
#  'COVID-19',
#  'information',
#  'page',
#  'at',
#  'https://t.co/ODG26qN36f',
#  'https://t.co/56jOZNdlVX',
#  'Petition:',
#  'Implement',
#  'UK',
#  'lockdown',
#  'for',
#  'preventing',
#  'spread',
#  'of',
#  'COVID19',
#  'https://t.co/mHsb5C5qmg',
#  'I',
#  'pray',
#  'everyone',
#  'that',
#  'goes',
#  'to',
#  'church',
#  'today',
#  'dies',
#  'from',
#  'Coronavirus.',
#  'You',
#  'cannot',
#  'possibly',
#  'be',
#  'so',
#  'irresponsible',
#  'and',
#  'still',
#  'be',
#  'looking',
#  'for',
#  'sympathy',
#  '😒',
#  'Come',
#  'and',
#  'see',
#  "Mamukokoot's",
#  'LIVE',
#  'in',
#  '#BIGOLIVE:',
#  'KWSP',
#  'COVID19',
#  'https://t.co/9CmsrulzR4',
#  'https://t.co/CP0GmRcEOU',
#  'How',
#  'did',
#  'Bill',
#  'Gates',
#  '&amp;',
#  'his',
#  'Netflix',
#  'Pandemic',
#  'know',
#  'the',
#  'CoronaVirus',
#  'was',
#  'coming?',
#  'Some',
#  'say',
#  'he',
#  'funded',
#  'it.',
#  'Makes',
#  'you',
#  'think',
#  'bigger',
#  'picture',
#  'https://t.co/YGAhhZyDMx',
#  'Enormous',
#  'thanks',
#  '&amp;',
#  'respect',
#  'to',
#  'Dentaa',
#  'Amoateng',
#  '@Dentaa_show,',
#  'queen',
#  'of',
#  'the',
#  'British-Ghanaian',
#  'community,',
#  'who',
#  'has',
#  'voluntarily',
#  'returned',
#  'to',
#  'her',
#  'old',
#  'job',
#  'as',
#  'a',
#  'nurse',
#  'at',
#  'the',
#  'Royal',
#  'Free',
#  'Hospital',
#  'to',
#  'treat',
#  '#coronavirus',
#  'patients.',
#  'Outstanding,',
#  'superb,',
#  'humbling',
#  '#COVID19',
#  '#covid19Canada',
#  'Retweet’s',
#  '#coronavirus',
#  '"Critical',
#  'Medical',
#  'Supply',
#  'Shortage":',
#  'The',
#  'Moment',
#  'US',
#  'Woke',
#  'Up',
#  'To',
#  'Disaster',
#  'Of',
#  'Always',
#  'Outsourcing',
#  'To',
#  '#China',
#  'https://t.co/qtrtjuUv6X',
#  'Some',
#  'useful',
#  'ideas',
#  'on',
#  'how',
#  'to',
#  'survive',
#  'being',
#  'at',
#  'home.',
#  'https://t.co/evPir6XJ9F',
#  '@ThelmaChen',
#  '@FreedomFreddy55',
#  'I',
#  'don’t',
#  'know',
#  'about',
#  'you',
#  'but',
#  'I',
#  'would',
#  'rather',
#  'this',
#  'virus',
#  'kill',
#  'me',
#  'than',
#  'to',
#  'live',
#  'in',
#  'fear.',
#  '#COVIDIOT',
#  '#QuaratineLife',
#  '#QuarantineActivities',
#  '#lockdown',
#  '#COVID19',
#  'This',
#  'COVID19',
#  'is',
#  'very',
#  'real',
#  'people',
#  'please',
#  'take',
#  'it',
#  'seriously',
#  '-👩🏼\u200d⚕️',
#  'Sunday',
#  'morning',
#  'scaries',
#  'https://t.co/JgHXeVLPFK',
#  'It',
#  'really',
#  'took',
#  'the',
#  'coronavirus',
#  'for',
#  'millennials',
#  'to',
#  'throw',
#  'gen',
#  'z',
#  'under',
#  'the',
#  'bus💀💀']

# %%
# len(tokens)
# Out:
# 646
